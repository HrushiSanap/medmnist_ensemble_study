# %% [markdown]
# ## Install and Imports

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"

# !pip install -q medmnist transformers tf-keras

import medmnist
from medmnist import INFO
import numpy as np
import os
import gc
import tensorflow as tf
from tensorflow.keras import layers, models, applications, mixed_precision
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from transformers import TFViTForImageClassification, TFSwinForImageClassification
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score, log_loss
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 5.5 MB/s eta 0:00:00
# 2026-02-12 05:18:49.607582: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770873529.790906      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770873529.840775      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770873530.263387      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770873530.263436      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770873530.263439      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770873530.263441      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
print(f"Legacy Keras Enabled: {str(os.environ.get('TF_USE_LEGACY_KERAS'))}")
# Out:
# Legacy Keras Enabled: 1

# %%
# CONFIGURATION 
DATASET = 'dermamnist'
BATCH_SIZE = 8 
EPOCHS = 30

# %%
# MIXED PRECISION SETUP 
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
print(f"Policy: {policy.name} | Compute: {policy.compute_dtype}")
# Out:
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   Tesla P100-PCIE-16GB, compute capability 6.0
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once
# Policy: mixed_float16 | Compute: float16

# %% [markdown]
# ## Data Loader Function

# %%
# Function: Data Loader
def load_medmnist_data(dataset_flag, size=224, batch_size=8):
    info = INFO[dataset_flag]
    n_classes = len(info['label'])
    DataClass = getattr(medmnist, info['python_class'])

    print(f"Loading {dataset_flag}...")
    train_data = DataClass(split='train', download=True, size=size)
    val_data = DataClass(split='val', download=True, size=size)
    test_data = DataClass(split='test', download=True, size=size)

    X_train, y_train = train_data.imgs, train_data.labels
    X_val, y_val = val_data.imgs, val_data.labels
    X_test, y_test = test_data.imgs, test_data.labels

    if X_train.shape[-1] != 3:
        X_train = np.repeat(X_train[..., np.newaxis], 3, -1)
        X_val = np.repeat(X_val[..., np.newaxis], 3, -1)
        X_test = np.repeat(X_test[..., np.newaxis], 3, -1)

    X_train = X_train.astype('float32')
    X_val = X_val.astype('float32')
    X_test = X_test.astype('float32')

    y_train_enc = to_categorical(y_train, n_classes)
    y_val_enc = to_categorical(y_val, n_classes)
    y_test_enc = to_categorical(y_test, n_classes)

    train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train_enc))\
        .shuffle(1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val_enc)).batch(batch_size)
    test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test_enc)).batch(batch_size)

    return train_ds, val_ds, test_ds, n_classes, y_test, X_test

# %% [markdown]
# ## Model Loader Function

# %%
# Function: Model Loader 
def get_model(model_name, n_classes, input_shape=(224, 224, 3)):
    inputs = layers.Input(shape=input_shape)
    
    if model_name == 'EfficientNetV2M':
        base = applications.EfficientNetV2M(include_top=False, weights='imagenet', input_tensor=inputs)
        x = layers.GlobalAveragePooling2D()(base.output)
        # Force float32 for stability in final layer
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)
        return models.Model(inputs=inputs, outputs=outputs, name=model_name)

    elif model_name == 'InceptionResNetV2':
        x = layers.Rescaling(1./127.5, offset=-1)(inputs)
        base = applications.InceptionResNetV2(include_top=False, weights='imagenet', input_tensor=x)
        x = layers.GlobalAveragePooling2D()(base.output)
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)
        return models.Model(inputs=inputs, outputs=outputs, name=model_name)

    elif model_name == 'ConvNeXtBase':
        base = applications.ConvNeXtBase(include_top=False, weights='imagenet', input_tensor=inputs)
        x = layers.GlobalAveragePooling2D()(base.output)
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)
        return models.Model(inputs=inputs, outputs=outputs, name=model_name)

    elif model_name == 'ViT-Base':
        x = layers.Rescaling(1./127.5, offset=-1)(inputs)
        x = layers.Permute((3, 1, 2))(x)
        backbone = TFViTForImageClassification.from_pretrained(
            'google/vit-base-patch16-224', num_labels=n_classes, 
            ignore_mismatched_sizes=True, use_safetensors=False)
        outputs = backbone.vit(x)[0]
        outputs = backbone.classifier(outputs[:, 0, :])
        outputs = layers.Activation('softmax', dtype='float32')(outputs)
        return models.Model(inputs=inputs, outputs=outputs, name=model_name)

    else:
        raise ValueError("Unknown Model")

# %% [markdown]
# ## Trainer Function

# %%
# Function: Model Trainer
def train_and_save(model_name):
    print(f"\n{'='*20} TRAINING {model_name} {'='*20}")
    tf.keras.backend.clear_session()
    gc.collect()
    
    if os.path.exists(f"{model_name}_{DATASET}.keras"):
        print(f"Found existing model: {model_name}_{DATASET}.keras. Loading weights...")
        model = get_model(model_name, n_classes)
        model.load_weights(f"{model_name}_{DATASET}.keras")
        
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    else:
        # Train from scratch
        model = get_model(model_name, n_classes)
        lr = 2e-5 if model_name in ['ViT-Base'] else 1e-4
        model.compile(optimizer=tf.keras.optimizers.Adam(lr), 
                      loss='categorical_crossentropy', metrics=['accuracy'])
        
        callbacks = [
            ModelCheckpoint(f"{model_name}_{DATASET}.keras", save_best_only=True, monitor='val_accuracy', mode='max', verbose=1),
            ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1),
            EarlyStopping(monitor='val_accuracy', patience=7, restore_best_weights=True, verbose=1)
        ]
        model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS, callbacks=callbacks, verbose=1)
        # Load best weights
        model.load_weights(f"{model_name}_{DATASET}.keras")

    # Generate Predictions
    print(f"Generating predictions for {model_name}...")
    
    # Validation Set
    val_preds = model.predict(val_ds)
    np.save(f"{model_name}_val_preds.npy", val_preds)
    
    # Test Set
    test_preds = model.predict(test_ds)
    np.save(f"{model_name}_preds.npy", test_preds)
    
    # Test Accuracy
    acc = accuracy_score(y_true_flat, np.argmax(test_preds, axis=1))
    print(f"{model_name} Test Accuracy: {acc:.4f}")
    
    del model
    gc.collect()
    return acc

# %%
# LOAD DATA
train_ds, val_ds, test_ds, n_classes, y_test_true, X_test_raw = load_medmnist_data(DATASET, batch_size=BATCH_SIZE)
y_true_flat = y_test_true.flatten()
y_true_cat = to_categorical(y_true_flat, n_classes)
print(f"Data Ready. Classes: {n_classes}")
# Out:
# Loading dermamnist...
# 100%|██████████| 1.09G/1.09G [01:22<00:00, 13.3MB/s]
# I0000 00:00:1770873651.818919      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Data Ready. Classes: 7

# %% [markdown]
# ## Training

# %%
train_and_save('ViT-Base')
# Out:
# ==================== TRAINING ViT-Base ====================
# config.json: 0.00B [00:00, ?B/s]
# tf_model.h5:   0%|          | 0.00/347M [00:00<?, ?B/s]
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# All model checkpoint layers were used when initializing TFViTForImageClassification.
#
# Some weights of TFViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier/kernel:0: found shape (768, 1000) in the checkpoint and (768, 7) in the model instantiated
# - classifier/bias:0: found shape (1000,) in the checkpoint and (7,) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30
# I0000 00:00:1770873702.429875     128 cuda_dnn.cc:529] Loaded cuDNN version 91002
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1770873704.260004     129 service.cc:152] XLA service 0x7f2f989665d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1770873704.260044     129 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1770873704.693521     129 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 876/876 [==============================] - ETA: 0s - loss: 0.6068 - accuracy: 0.7826
# Epoch 1: val_accuracy improved from -inf to 0.85743, saving model to ViT-Base_dermamnist.keras
# 876/876 [==============================] - 275s 253ms/step - loss: 0.6068 - accuracy: 0.7826 - val_loss: 0.4256 - val_accuracy: 0.8574 - lr: 2.0000e-05
# Epoch 2/30
# 876/876 [==============================] - ETA: 0s - loss: 0.2972 - accuracy: 0.8985
# Epoch 2: val_accuracy improved from 0.85743 to 0.87039, saving model to ViT-Base_dermamnist.keras
# 876/876 [==============================] - 218s 249ms/step - loss: 0.2972 - accuracy: 0.8985 - val_loss: 0.3646 - val_accuracy: 0.8704 - lr: 2.0000e-05
# Epoch 3/30
# 876/876 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9593
# Epoch 3: val_accuracy did not improve from 0.87039
# 876/876 [==============================] - 212s 242ms/step - loss: 0.1275 - accuracy: 0.9593 - val_loss: 0.3900 - val_accuracy: 0.8684 - lr: 2.0000e-05
# Epoch 4/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9872
# Epoch 4: val_accuracy improved from 0.87039 to 0.87537, saving model to ViT-Base_dermamnist.keras
# 876/876 [==============================] - 218s 249ms/step - loss: 0.0490 - accuracy: 0.9872 - val_loss: 0.4368 - val_accuracy: 0.8754 - lr: 2.0000e-05
# Epoch 5/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9892
# Epoch 5: val_accuracy did not improve from 0.87537
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 876/876 [==============================] - 212s 242ms/step - loss: 0.0346 - accuracy: 0.9892 - val_loss: 0.5081 - val_accuracy: 0.8654 - lr: 2.0000e-05
# Epoch 6/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9976
# Epoch 6: val_accuracy improved from 0.87537 to 0.88435, saving model to ViT-Base_dermamnist.keras
# 876/876 [==============================] - 218s 249ms/step - loss: 0.0102 - accuracy: 0.9976 - val_loss: 0.4173 - val_accuracy: 0.8843 - lr: 1.0000e-05
# Epoch 7/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 7: val_accuracy improved from 0.88435 to 0.89432, saving model to ViT-Base_dermamnist.keras
# 876/876 [==============================] - 218s 249ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4179 - val_accuracy: 0.8943 - lr: 1.0000e-05
# Epoch 8/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 8: val_accuracy improved from 0.89432 to 0.89831, saving model to ViT-Base_dermamnist.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 876/876 [==============================] - 218s 249ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4358 - val_accuracy: 0.8983 - lr: 1.0000e-05
# Epoch 9/30
# 876/876 [==============================] - ETA: 0s - loss: 7.0496e-04 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.89831
# 876/876 [==============================] - 211s 241ms/step - loss: 7.0496e-04 - accuracy: 1.0000 - val_loss: 0.4453 - val_accuracy: 0.8973 - lr: 5.0000e-06
# Epoch 10/30
# 876/876 [==============================] - ETA: 0s - loss: 5.5282e-04 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.89831
# 876/876 [==============================] - 211s 241ms/step - loss: 5.5282e-04 - accuracy: 1.0000 - val_loss: 0.4584 - val_accuracy: 0.8973 - lr: 5.0000e-06
# Epoch 11/30
# 876/876 [==============================] - ETA: 0s - loss: 4.1686e-04 - accuracy: 1.0000
# Epoch 11: val_accuracy improved from 0.89831 to 0.89930, saving model to ViT-Base_dermamnist.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 876/876 [==============================] - 218s 249ms/step - loss: 4.1686e-04 - accuracy: 1.0000 - val_loss: 0.4746 - val_accuracy: 0.8993 - lr: 5.0000e-06
# Epoch 12/30
# 876/876 [==============================] - ETA: 0s - loss: 3.2220e-04 - accuracy: 1.0000
# Epoch 12: val_accuracy improved from 0.89930 to 0.90030, saving model to ViT-Base_dermamnist.keras
# 876/876 [==============================] - 218s 249ms/step - loss: 3.2220e-04 - accuracy: 1.0000 - val_loss: 0.4834 - val_accuracy: 0.9003 - lr: 2.5000e-06
# Epoch 13/30
# 876/876 [==============================] - ETA: 0s - loss: 2.6462e-04 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.90030
# 876/876 [==============================] - 212s 242ms/step - loss: 2.6462e-04 - accuracy: 1.0000 - val_loss: 0.4953 - val_accuracy: 0.9003 - lr: 2.5000e-06
# Epoch 14/30
# 876/876 [==============================] - ETA: 0s - loss: 2.0808e-04 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.90030
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 876/876 [==============================] - 211s 241ms/step - loss: 2.0808e-04 - accuracy: 1.0000 - val_loss: 0.5110 - val_accuracy: 0.9003 - lr: 2.5000e-06
# Epoch 15/30
# 876/876 [==============================] - ETA: 0s - loss: 1.6609e-04 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.90030
# 876/876 [==============================] - 212s 242ms/step - loss: 1.6609e-04 - accuracy: 1.0000 - val_loss: 0.5199 - val_accuracy: 0.8993 - lr: 1.2500e-06
# Epoch 16/30
# 876/876 [==============================] - ETA: 0s - loss: 1.3950e-04 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.90030
# 876/876 [==============================] - 212s 242ms/step - loss: 1.3950e-04 - accuracy: 1.0000 - val_loss: 0.5315 - val_accuracy: 0.8993 - lr: 1.2500e-06
# Epoch 17/30
# 876/876 [==============================] - ETA: 0s - loss: 1.1286e-04 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.90030
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1e-06.
# 876/876 [==============================] - 211s 241ms/step - loss: 1.1286e-04 - accuracy: 1.0000 - val_loss: 0.5467 - val_accuracy: 0.8983 - lr: 1.2500e-06
# Epoch 18/30
# 876/876 [==============================] - ETA: 0s - loss: 8.9722e-05 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.90030
# 876/876 [==============================] - 212s 242ms/step - loss: 8.9722e-05 - accuracy: 1.0000 - val_loss: 0.5621 - val_accuracy: 0.8983 - lr: 1.0000e-06
# Epoch 19/30
# 876/876 [==============================] - ETA: 0s - loss: 7.1569e-05 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.90030
# 876/876 [==============================] - 211s 241ms/step - loss: 7.1569e-05 - accuracy: 1.0000 - val_loss: 0.5796 - val_accuracy: 0.8993 - lr: 1.0000e-06
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Generating predictions for ViT-Base...
# 126/126 [==============================] - 12s 78ms/step
# 251/251 [==============================] - 20s 78ms/step
# ViT-Base Test Accuracy: 0.9067
# 0.9067331670822942

# %%
train_and_save('ConvNeXtBase')
# Out:
# ==================== TRAINING ConvNeXtBase ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 [==============================] - 1s 0us/step
# Epoch 1/30
# 2026-02-12 06:32:02.347987: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 06:32:02.532469: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 06:32:02.802884: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 06:32:03.012367: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 875/876 [============================>.] - ETA: 0s - loss: 0.6828 - accuracy: 0.7637
# 2026-02-12 06:38:01.490159: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 06:38:01.674646: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 06:38:01.917459: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 06:38:02.126251: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 876/876 [==============================] - ETA: 0s - loss: 0.6825 - accuracy: 0.7638
# Epoch 1: val_accuracy improved from -inf to 0.82951, saving model to ConvNeXtBase_dermamnist.keras
# 876/876 [==============================] - 569s 506ms/step - loss: 0.6825 - accuracy: 0.7638 - val_loss: 0.4678 - val_accuracy: 0.8295 - lr: 1.0000e-04
# Epoch 2/30
# 876/876 [==============================] - ETA: 0s - loss: 0.3219 - accuracy: 0.8823
# Epoch 2: val_accuracy improved from 0.82951 to 0.84646, saving model to ConvNeXtBase_dermamnist.keras
# 876/876 [==============================] - 266s 304ms/step - loss: 0.3219 - accuracy: 0.8823 - val_loss: 0.3989 - val_accuracy: 0.8465 - lr: 1.0000e-04
# Epoch 3/30
# 876/876 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9500
# Epoch 3: val_accuracy improved from 0.84646 to 0.87637, saving model to ConvNeXtBase_dermamnist.keras
# 876/876 [==============================] - 268s 305ms/step - loss: 0.1364 - accuracy: 0.9500 - val_loss: 0.4511 - val_accuracy: 0.8764 - lr: 1.0000e-04
# Epoch 4/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9733
# Epoch 4: val_accuracy did not improve from 0.87637
# 876/876 [==============================] - 260s 297ms/step - loss: 0.0775 - accuracy: 0.9733 - val_loss: 0.4950 - val_accuracy: 0.8644 - lr: 1.0000e-04
# Epoch 5/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9802
# Epoch 5: val_accuracy did not improve from 0.87637
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 876/876 [==============================] - 259s 296ms/step - loss: 0.0641 - accuracy: 0.9802 - val_loss: 0.4899 - val_accuracy: 0.8584 - lr: 1.0000e-04
# Epoch 6/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9977
# Epoch 6: val_accuracy improved from 0.87637 to 0.89332, saving model to ConvNeXtBase_dermamnist.keras
# 876/876 [==============================] - 266s 304ms/step - loss: 0.0102 - accuracy: 0.9977 - val_loss: 0.4139 - val_accuracy: 0.8933 - lr: 5.0000e-05
# Epoch 7/30
# 876/876 [==============================] - ETA: 0s - loss: 7.9768e-04 - accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 0.89332
# 876/876 [==============================] - 259s 296ms/step - loss: 7.9768e-04 - accuracy: 1.0000 - val_loss: 0.4276 - val_accuracy: 0.8923 - lr: 5.0000e-05
# Epoch 8/30
# 876/876 [==============================] - ETA: 0s - loss: 1.2459e-04 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.89332
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 876/876 [==============================] - 259s 295ms/step - loss: 1.2459e-04 - accuracy: 1.0000 - val_loss: 0.4485 - val_accuracy: 0.8933 - lr: 5.0000e-05
# Epoch 9/30
# 876/876 [==============================] - ETA: 0s - loss: 6.2898e-05 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.89332
# 876/876 [==============================] - 258s 295ms/step - loss: 6.2898e-05 - accuracy: 1.0000 - val_loss: 0.4626 - val_accuracy: 0.8933 - lr: 2.5000e-05
# Epoch 10/30
# 876/876 [==============================] - ETA: 0s - loss: 4.6290e-05 - accuracy: 1.0000
# Epoch 10: val_accuracy improved from 0.89332 to 0.89432, saving model to ConvNeXtBase_dermamnist.keras
# 876/876 [==============================] - 266s 303ms/step - loss: 4.6290e-05 - accuracy: 1.0000 - val_loss: 0.4753 - val_accuracy: 0.8943 - lr: 2.5000e-05
# Epoch 11/30
# 876/876 [==============================] - ETA: 0s - loss: 3.3140e-05 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.89432
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 876/876 [==============================] - 258s 295ms/step - loss: 3.3140e-05 - accuracy: 1.0000 - val_loss: 0.4900 - val_accuracy: 0.8943 - lr: 2.5000e-05
# Epoch 12/30
# 876/876 [==============================] - ETA: 0s - loss: 2.4417e-05 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.89432
# 876/876 [==============================] - 258s 295ms/step - loss: 2.4417e-05 - accuracy: 1.0000 - val_loss: 0.4999 - val_accuracy: 0.8943 - lr: 1.2500e-05
# Epoch 13/30
# 876/876 [==============================] - ETA: 0s - loss: 1.9394e-05 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.89432
# 876/876 [==============================] - 258s 294ms/step - loss: 1.9394e-05 - accuracy: 1.0000 - val_loss: 0.5109 - val_accuracy: 0.8943 - lr: 1.2500e-05
# Epoch 14/30
# 876/876 [==============================] - ETA: 0s - loss: 1.4620e-05 - accuracy: 1.0000
# Epoch 14: val_accuracy improved from 0.89432 to 0.89531, saving model to ConvNeXtBase_dermamnist.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 876/876 [==============================] - 266s 304ms/step - loss: 1.4620e-05 - accuracy: 1.0000 - val_loss: 0.5248 - val_accuracy: 0.8953 - lr: 1.2500e-05
# Epoch 15/30
# 876/876 [==============================] - ETA: 0s - loss: 1.1185e-05 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.89531
# 876/876 [==============================] - 259s 295ms/step - loss: 1.1185e-05 - accuracy: 1.0000 - val_loss: 0.5333 - val_accuracy: 0.8953 - lr: 6.2500e-06
# Epoch 16/30
# 876/876 [==============================] - ETA: 0s - loss: 9.0677e-06 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.89531
# 876/876 [==============================] - 258s 295ms/step - loss: 9.0677e-06 - accuracy: 1.0000 - val_loss: 0.5442 - val_accuracy: 0.8943 - lr: 6.2500e-06
# Epoch 17/30
# 876/876 [==============================] - ETA: 0s - loss: 7.0029e-06 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.89531
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 876/876 [==============================] - 258s 294ms/step - loss: 7.0029e-06 - accuracy: 1.0000 - val_loss: 0.5570 - val_accuracy: 0.8943 - lr: 6.2500e-06
# Epoch 18/30
# 876/876 [==============================] - ETA: 0s - loss: 5.4695e-06 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.89531
# 876/876 [==============================] - 258s 294ms/step - loss: 5.4695e-06 - accuracy: 1.0000 - val_loss: 0.5653 - val_accuracy: 0.8943 - lr: 3.1250e-06
# Epoch 19/30
# 876/876 [==============================] - ETA: 0s - loss: 4.5200e-06 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.89531
# 876/876 [==============================] - 258s 294ms/step - loss: 4.5200e-06 - accuracy: 1.0000 - val_loss: 0.5757 - val_accuracy: 0.8953 - lr: 3.1250e-06
# Epoch 20/30
# 876/876 [==============================] - ETA: 0s - loss: 3.5750e-06 - accuracy: 1.0000
# Epoch 20: val_accuracy improved from 0.89531 to 0.89631, saving model to ConvNeXtBase_dermamnist.keras
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 876/876 [==============================] - 265s 302ms/step - loss: 3.5750e-06 - accuracy: 1.0000 - val_loss: 0.5880 - val_accuracy: 0.8963 - lr: 3.1250e-06
# Epoch 21/30
# 876/876 [==============================] - ETA: 0s - loss: 2.8712e-06 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.89631
# 876/876 [==============================] - 258s 295ms/step - loss: 2.8712e-06 - accuracy: 1.0000 - val_loss: 0.5956 - val_accuracy: 0.8963 - lr: 1.5625e-06
# Epoch 22/30
# 876/876 [==============================] - ETA: 0s - loss: 2.4333e-06 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.89631
# 876/876 [==============================] - 258s 294ms/step - loss: 2.4333e-06 - accuracy: 1.0000 - val_loss: 0.6039 - val_accuracy: 0.8963 - lr: 1.5625e-06
# Epoch 23/30
# 876/876 [==============================] - ETA: 0s - loss: 2.0021e-06 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.89631
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-06.
# 876/876 [==============================] - 258s 295ms/step - loss: 2.0021e-06 - accuracy: 1.0000 - val_loss: 0.6143 - val_accuracy: 0.8963 - lr: 1.5625e-06
# Epoch 24/30
# 876/876 [==============================] - ETA: 0s - loss: 1.6538e-06 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.89631
# 876/876 [==============================] - 258s 295ms/step - loss: 1.6538e-06 - accuracy: 1.0000 - val_loss: 0.6219 - val_accuracy: 0.8963 - lr: 1.0000e-06
# Epoch 25/30
# 876/876 [==============================] - ETA: 0s - loss: 1.4070e-06 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.89631
# 876/876 [==============================] - 258s 295ms/step - loss: 1.4070e-06 - accuracy: 1.0000 - val_loss: 0.6305 - val_accuracy: 0.8963 - lr: 1.0000e-06
# Epoch 26/30
# 876/876 [==============================] - ETA: 0s - loss: 1.1775e-06 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.89631
# 876/876 [==============================] - 259s 295ms/step - loss: 1.1775e-06 - accuracy: 1.0000 - val_loss: 0.6396 - val_accuracy: 0.8963 - lr: 1.0000e-06
# Epoch 27/30
# 876/876 [==============================] - ETA: 0s - loss: 9.7357e-07 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.89631
# 876/876 [==============================] - 259s 295ms/step - loss: 9.7357e-07 - accuracy: 1.0000 - val_loss: 0.6489 - val_accuracy: 0.8963 - lr: 1.0000e-06
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Generating predictions for ConvNeXtBase...
# 126/126 [==============================] - 15s 97ms/step
# 251/251 [==============================] - 55s 220ms/step
# ConvNeXtBase Test Accuracy: 0.9167
# 0.9167082294264339

# %%
train_and_save('EfficientNetV2M')
# Out:
# ==================== TRAINING EfficientNetV2M ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 1s 0us/step
# Epoch 1/30
# E0000 00:00:1770885334.928174      55 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inEfficientNetV2M/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 876/876 [==============================] - ETA: 0s - loss: 0.7740 - accuracy: 0.7317
# Epoch 1: val_accuracy improved from -inf to 0.82253, saving model to EfficientNetV2M_dermamnist.keras
# 876/876 [==============================] - 404s 250ms/step - loss: 0.7740 - accuracy: 0.7317 - val_loss: 0.4794 - val_accuracy: 0.8225 - lr: 1.0000e-04
# Epoch 2/30
# 876/876 [==============================] - ETA: 0s - loss: 0.4551 - accuracy: 0.8370
# Epoch 2: val_accuracy improved from 0.82253 to 0.84447, saving model to EfficientNetV2M_dermamnist.keras
# 876/876 [==============================] - 183s 209ms/step - loss: 0.4551 - accuracy: 0.8370 - val_loss: 0.4524 - val_accuracy: 0.8445 - lr: 1.0000e-04
# Epoch 3/30
# 876/876 [==============================] - ETA: 0s - loss: 0.2968 - accuracy: 0.8965
# Epoch 3: val_accuracy did not improve from 0.84447
# 876/876 [==============================] - 177s 202ms/step - loss: 0.2968 - accuracy: 0.8965 - val_loss: 0.5313 - val_accuracy: 0.8305 - lr: 1.0000e-04
# Epoch 4/30
# 876/876 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9373
# Epoch 4: val_accuracy improved from 0.84447 to 0.86241, saving model to EfficientNetV2M_dermamnist.keras
# 876/876 [==============================] - 183s 209ms/step - loss: 0.1841 - accuracy: 0.9373 - val_loss: 0.4411 - val_accuracy: 0.8624 - lr: 1.0000e-04
# Epoch 5/30
# 876/876 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9585
# Epoch 5: val_accuracy improved from 0.86241 to 0.87836, saving model to EfficientNetV2M_dermamnist.keras
# 876/876 [==============================] - 183s 209ms/step - loss: 0.1220 - accuracy: 0.9585 - val_loss: 0.4858 - val_accuracy: 0.8784 - lr: 1.0000e-04
# Epoch 6/30
# 876/876 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9660
# Epoch 6: val_accuracy did not improve from 0.87836
# 876/876 [==============================] - 175s 200ms/step - loss: 0.1010 - accuracy: 0.9660 - val_loss: 0.6150 - val_accuracy: 0.8445 - lr: 1.0000e-04
# Epoch 7/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0852 - accuracy: 0.9709
# Epoch 7: val_accuracy did not improve from 0.87836
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 876/876 [==============================] - 176s 201ms/step - loss: 0.0852 - accuracy: 0.9709 - val_loss: 0.5948 - val_accuracy: 0.8624 - lr: 1.0000e-04
# Epoch 8/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0443 - accuracy: 0.9882
# Epoch 8: val_accuracy did not improve from 0.87836
# 876/876 [==============================] - 175s 200ms/step - loss: 0.0443 - accuracy: 0.9882 - val_loss: 0.5491 - val_accuracy: 0.8714 - lr: 5.0000e-05
# Epoch 9/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9933
# Epoch 9: val_accuracy did not improve from 0.87836
# 876/876 [==============================] - 175s 200ms/step - loss: 0.0213 - accuracy: 0.9933 - val_loss: 0.5656 - val_accuracy: 0.8754 - lr: 5.0000e-05
# Epoch 10/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9941
# Epoch 10: val_accuracy did not improve from 0.87836
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 876/876 [==============================] - 175s 200ms/step - loss: 0.0230 - accuracy: 0.9941 - val_loss: 0.5812 - val_accuracy: 0.8714 - lr: 5.0000e-05
# Epoch 11/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9966
# Epoch 11: val_accuracy did not improve from 0.87836
# 876/876 [==============================] - 176s 201ms/step - loss: 0.0127 - accuracy: 0.9966 - val_loss: 0.6248 - val_accuracy: 0.8754 - lr: 2.5000e-05
# Epoch 12/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9984
# Epoch 12: val_accuracy did not improve from 0.87836
# 876/876 [==============================] - 175s 199ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.6233 - val_accuracy: 0.8704 - lr: 2.5000e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Generating predictions for EfficientNetV2M...
# 126/126 [==============================] - 10s 44ms/step
# 251/251 [==============================] - 16s 66ms/step
# EfficientNetV2M Test Accuracy: 0.8678
# 0.8678304239401496

# %%
train_and_save('InceptionResNetV2')
# Out:
# ==================== TRAINING InceptionResNetV2 ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 1s 0us/step
# Epoch 1/30
# 876/876 [==============================] - ETA: 0s - loss: 0.7250 - accuracy: 0.7441
# Epoch 1: val_accuracy improved from -inf to 0.76969, saving model to InceptionResNetV2_dermamnist.keras
# 876/876 [==============================] - 360s 237ms/step - loss: 0.7250 - accuracy: 0.7441 - val_loss: 0.8393 - val_accuracy: 0.7697 - lr: 1.0000e-04
# Epoch 2/30
# 876/876 [==============================] - ETA: 0s - loss: 0.4598 - accuracy: 0.8367
# Epoch 2: val_accuracy improved from 0.76969 to 0.83848, saving model to InceptionResNetV2_dermamnist.keras
# 876/876 [==============================] - 167s 191ms/step - loss: 0.4598 - accuracy: 0.8367 - val_loss: 0.4499 - val_accuracy: 0.8385 - lr: 1.0000e-04
# Epoch 3/30
# 876/876 [==============================] - ETA: 0s - loss: 0.2948 - accuracy: 0.8932
# Epoch 3: val_accuracy did not improve from 0.83848
# 876/876 [==============================] - 161s 184ms/step - loss: 0.2948 - accuracy: 0.8932 - val_loss: 0.5766 - val_accuracy: 0.7946 - lr: 1.0000e-04
# Epoch 4/30
# 876/876 [==============================] - ETA: 0s - loss: 0.1774 - accuracy: 0.9371
# Epoch 4: val_accuracy did not improve from 0.83848
# 876/876 [==============================] - 161s 183ms/step - loss: 0.1774 - accuracy: 0.9371 - val_loss: 0.5667 - val_accuracy: 0.8345 - lr: 1.0000e-04
# Epoch 5/30
# 876/876 [==============================] - ETA: 0s - loss: 0.1225 - accuracy: 0.9583
# Epoch 5: val_accuracy did not improve from 0.83848
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 876/876 [==============================] - 160s 183ms/step - loss: 0.1225 - accuracy: 0.9583 - val_loss: 0.5588 - val_accuracy: 0.8255 - lr: 1.0000e-04
# Epoch 6/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0483 - accuracy: 0.9862
# Epoch 6: val_accuracy improved from 0.83848 to 0.85743, saving model to InceptionResNetV2_dermamnist.keras
# 876/876 [==============================] - 167s 190ms/step - loss: 0.0483 - accuracy: 0.9862 - val_loss: 0.7450 - val_accuracy: 0.8574 - lr: 5.0000e-05
# Epoch 7/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9894
# Epoch 7: val_accuracy improved from 0.85743 to 0.86042, saving model to InceptionResNetV2_dermamnist.keras
# 876/876 [==============================] - 167s 190ms/step - loss: 0.0331 - accuracy: 0.9894 - val_loss: 0.5231 - val_accuracy: 0.8604 - lr: 5.0000e-05
# Epoch 8/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9910
# Epoch 8: val_accuracy did not improve from 0.86042
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 876/876 [==============================] - 160s 182ms/step - loss: 0.0291 - accuracy: 0.9910 - val_loss: 0.7811 - val_accuracy: 0.8195 - lr: 5.0000e-05
# Epoch 9/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9967
# Epoch 9: val_accuracy did not improve from 0.86042
# 876/876 [==============================] - 159s 182ms/step - loss: 0.0151 - accuracy: 0.9967 - val_loss: 0.7907 - val_accuracy: 0.8405 - lr: 2.5000e-05
# Epoch 10/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9967
# Epoch 10: val_accuracy did not improve from 0.86042
# 876/876 [==============================] - 159s 181ms/step - loss: 0.0131 - accuracy: 0.9967 - val_loss: 0.7191 - val_accuracy: 0.8564 - lr: 2.5000e-05
# Epoch 11/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9971
# Epoch 11: val_accuracy did not improve from 0.86042
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 876/876 [==============================] - 158s 180ms/step - loss: 0.0101 - accuracy: 0.9971 - val_loss: 0.9092 - val_accuracy: 0.8265 - lr: 2.5000e-05
# Epoch 12/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9991
# Epoch 12: val_accuracy did not improve from 0.86042
# 876/876 [==============================] - 158s 180ms/step - loss: 0.0056 - accuracy: 0.9991 - val_loss: 0.8762 - val_accuracy: 0.8415 - lr: 1.2500e-05
# Epoch 13/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9977
# Epoch 13: val_accuracy did not improve from 0.86042
# 876/876 [==============================] - 158s 180ms/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.8560 - val_accuracy: 0.8495 - lr: 1.2500e-05
# Epoch 14/30
# 876/876 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9984
# Epoch 14: val_accuracy did not improve from 0.86042
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 876/876 [==============================] - 158s 180ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.7744 - val_accuracy: 0.8524 - lr: 1.2500e-05
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Generating predictions for InceptionResNetV2...
# 126/126 [==============================] - 9s 44ms/step
# 251/251 [==============================] - 12s 47ms/step
# InceptionResNetV2 Test Accuracy: 0.8723
# 0.8723192019950124

# %% [markdown]
# ## Ensemble (Soft Voting) & Results

# %%
# ENSEMBLE ANALYSIS 
print(f"\n{'='*30}\nENSEMBLE EXECUTION\n{'='*30}")

MODELS_TO_LOAD = ['ConvNeXtBase', 'ViT-Base', 'EfficientNetV2M', 'InceptionResNetV2']
loaded_preds = []
valid_models = []

for m in MODELS_TO_LOAD:
    filename = f"{m}_preds.npy"
    if os.path.exists(filename):
        print(f"Loading {filename}...")
        loaded_preds.append(np.load(filename))
        valid_models.append(m)
    else:
        print(f"Warning: {filename} not found. Skipping.")

if not loaded_preds:
    raise ValueError("No predictions found! Train at least one model first.")

# Stack and Average
all_preds = np.array(loaded_preds) # Shape: (Num_Models, N_Samples, N_Classes)
ensemble_probs = np.mean(all_preds, axis=0)

y_pred_ensemble = np.argmax(ensemble_probs, axis=1)

# Metrics
print("\n>>> Classification Report:")
print(classification_report(y_true_flat, y_pred_ensemble))

ens_acc = accuracy_score(y_true_flat, y_pred_ensemble)
ens_auc = roc_auc_score(y_true_cat, ensemble_probs, multi_class='ovr')
ens_loss = log_loss(y_true_cat, ensemble_probs)

print(f"Ensemble Accuracy: {ens_acc:.4f}")
print(f"Ensemble AUC:      {ens_auc:.4f}")

fig, axes = plt.subplots(1, 3, figsize=(20, 5))

# Confusion Matrix
cm = confusion_matrix(y_true_flat, y_pred_ensemble)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title(f'Ensemble Confusion Matrix (Acc: {ens_acc:.2%})')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('True')

# Uncertainty (Entropy)
entropy = -np.sum(ensemble_probs * np.log(ensemble_probs + 1e-9), axis=1)
correct_mask = (y_pred_ensemble == y_true_flat)

sns.kdeplot(entropy[correct_mask], label='Correct', fill=True, color='green', ax=axes[1])
sns.kdeplot(entropy[~correct_mask], label='Wrong', fill=True, color='red', ax=axes[1])
axes[1].set_title('Uncertainty (Entropy) Distribution')
axes[1].legend()

# Calibration (Top-Class)
is_correct = (y_pred_ensemble == y_true_flat).astype(int)
pred_confidence = np.max(ensemble_probs, axis=1)
prob_true, prob_pred = calibration_curve(is_correct, pred_confidence, n_bins=10, strategy='quantile')

axes[2].plot(prob_pred, prob_true, marker='o', label='Ensemble', color='purple')
axes[2].plot([0, 1], [0, 1], linestyle='--', color='gray', label='Perfect')
axes[2].set_title('Reliability Diagram')
axes[2].set_xlabel('Confidence')
axes[2].set_ylabel('Accuracy')
axes[2].legend()
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ==============================
# ENSEMBLE EXECUTION
# ==============================
# Loading ConvNeXtBase_preds.npy...
# Loading ViT-Base_preds.npy...
# Loading EfficientNetV2M_preds.npy...
# Loading InceptionResNetV2_preds.npy...
#
# >>> Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81        66
#            1       0.85      0.93      0.89       103
#            2       0.88      0.81      0.84       220
#            3       0.94      0.70      0.80        23
#            4       0.85      0.72      0.78       223
#            5       0.94      0.98      0.96      1341
#            6       0.94      1.00      0.97        29
#
#     accuracy                           0.92      2005
#    macro avg       0.89      0.84      0.86      2005
# weighted avg       0.92      0.92      0.92      2005
#
# Ensemble Accuracy: 0.9197
# Ensemble AUC:      0.9898

# %% [markdown]
# ## Individual Model Results

# %%
MODELS_TO_LOAD = ['ConvNeXtBase', 'ViT-Base', 'EfficientNetV2M', 'InceptionResNetV2']

print(f"\n{'='*50}\nINDIVIDUAL MODEL DIAGNOSTICS\n{'='*50}")

model_scores = {}

for model_name in MODELS_TO_LOAD:
    filename = f"{model_name}_preds.npy"
    
    if not os.path.exists(filename):
        print(f"Warning: {filename} not found. Skipping.")
        continue

    # Load Predictions
    preds_probs = np.load(filename)
    y_pred = np.argmax(preds_probs, axis=1)

    # Calculate Metrics
    acc = accuracy_score(y_true_flat, y_pred)
    auc = roc_auc_score(y_true_cat, preds_probs, multi_class='ovr')
    model_scores[model_name] = acc

    print(f"\n{'='*20} {model_name} {'='*20}")
    print(f"Accuracy: {acc:.4%}")
    print(f"AUC:      {auc:.4f}")
    print("-" * 60)
    print(classification_report(y_true_flat, y_pred))

    # Plotting Suite
    fig, axes = plt.subplots(1, 3, figsize=(20, 5))

    # Confusion Matrix
    cm = confusion_matrix(y_true_flat, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', ax=axes[0])
    axes[0].set_title(f'{model_name} Confusion Matrix')
    axes[0].set_xlabel('Predicted Label')
    axes[0].set_ylabel('True Label')

    # Uncertainty (Entropy) Distribution
    entropy = -np.sum(preds_probs * np.log(preds_probs + 1e-9), axis=1)
    correct_mask = (y_pred == y_true_flat)
    
    sns.kdeplot(entropy[correct_mask], label='Correct', fill=True, color='green', ax=axes[1])
    sns.kdeplot(entropy[~correct_mask], label='Wrong', fill=True, color='red', ax=axes[1])
    axes[1].set_title(f'{model_name} Uncertainty Profile')
    axes[1].set_xlabel('Entropy (Uncertainty)')
    axes[1].legend()

    # Reliability Diagram (Calibration)
    is_correct = (y_pred == y_true_flat).astype(int)
    pred_conf = np.max(preds_probs, axis=1)
    prob_true, prob_pred = calibration_curve(is_correct, pred_conf, n_bins=10, strategy='quantile')
    
    axes[2].plot(prob_pred, prob_true, marker='o', label=model_name, color='darkorange')
    axes[2].plot([0, 1], [0, 1], linestyle='--', color='gray', label='Perfect')
    axes[2].set_title(f'{model_name} Reliability')
    axes[2].set_xlabel('Confidence')
    axes[2].set_ylabel('Accuracy')
    axes[2].legend()
    axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# Summary Comparison Table
print("\n" + "="*30)
print("FINAL PERFORMANCE SUMMARY")
print("="*30)
print(f"{'Model Name':<20} | {'Accuracy':<10}")
print("-" * 35)
for name, score in model_scores.items():
    print(f"{name:<20} | {score:.4%}")
print("-" * 35)
# Out:
# ==================================================
# INDIVIDUAL MODEL DIAGNOSTICS
# ==================================================
#
# ==================== ConvNeXtBase ====================
# Accuracy: 91.6708%
# AUC:      0.9884
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81        66
#            1       0.91      0.90      0.91       103
#            2       0.89      0.82      0.85       220
#            3       0.94      0.70      0.80        23
#            4       0.75      0.77      0.76       223
#            5       0.95      0.97      0.96      1341
#            6       1.00      0.93      0.96        29
#
#     accuracy                           0.92      2005
#    macro avg       0.90      0.84      0.86      2005
# weighted avg       0.92      0.92      0.92      2005
# ==================== ViT-Base ====================
# Accuracy: 90.6733%
# AUC:      0.9856
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.84      0.74      0.79        66
#            1       0.84      0.89      0.86       103
#            2       0.80      0.82      0.81       220
#            3       0.94      0.65      0.77        23
#            4       0.78      0.75      0.77       223
#            5       0.95      0.96      0.96      1341
#            6       0.96      0.90      0.93        29
#
#     accuracy                           0.91      2005
#    macro avg       0.87      0.82      0.84      2005
# weighted avg       0.91      0.91      0.91      2005
# ==================== EfficientNetV2M ====================
# Accuracy: 86.7830%
# AUC:      0.9743
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.72      0.55      0.62        66
#            1       0.68      0.87      0.77       103
#            2       0.78      0.70      0.74       220
#            3       0.65      0.65      0.65        23
#            4       0.78      0.60      0.68       223
#            5       0.92      0.96      0.94      1341
#            6       0.73      0.93      0.82        29
#
#     accuracy                           0.87      2005
#    macro avg       0.75      0.75      0.74      2005
# weighted avg       0.87      0.87      0.86      2005
# ==================== InceptionResNetV2 ====================
# Accuracy: 87.2319%
# AUC:      0.9714
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.79      0.69        66
#            1       0.72      0.84      0.78       103
#            2       0.81      0.73      0.77       220
#            3       0.78      0.61      0.68        23
#            4       0.81      0.54      0.65       223
#            5       0.92      0.96      0.94      1341
#            6       0.67      0.90      0.76        29
#
#     accuracy                           0.87      2005
#    macro avg       0.76      0.77      0.75      2005
# weighted avg       0.87      0.87      0.87      2005
# ==============================
# FINAL PERFORMANCE SUMMARY
# ==============================
# Model Name           | Accuracy
# -----------------------------------
# ConvNeXtBase         | 91.6708%
# ViT-Base             | 90.6733%
# EfficientNetV2M      | 86.7830%
# InceptionResNetV2    | 87.2319%
# -----------------------------------

# %% [markdown]
# ## Stacking & Results

# %%
from tensorflow.keras import  callbacks 

print(f"\n{'='*30}\nRIGOROUS STACKING (No Data Leakage)\n{'='*30}")
MODELS_TO_LOAD = ['ConvNeXtBase', 'ViT-Base', 'EfficientNetV2M', 'InceptionResNetV2']

# training meta-data  (From Validation Set)
print("Loading VALIDATION predictions (Meta-Train)...")
val_preds_list = []
for m in MODELS_TO_LOAD:
    filename = f"{m}_val_preds.npy"
    if os.path.exists(filename):
        val_preds_list.append(np.load(filename))
    else:
        raise ValueError(f"Missing validation preds for {m}. Re-run training cell.")

X_meta_train = np.concatenate(val_preds_list, axis=1) # (N_Val, 32)

# labels for the validation set
y_val_true = np.concatenate([y for x, y in val_ds], axis=0)
y_val_flat = np.argmax(y_val_true, axis=1)

print(f"Meta-Train Input Shape: {X_meta_train.shape}")


# testing meta-data (From Test Set) 
print("Loading TEST predictions (Meta-Eval)...")
test_preds_list = []
for m in MODELS_TO_LOAD:
    filename = f"{m}_preds.npy"
    if os.path.exists(filename):
        test_preds_list.append(np.load(filename))
    else:
        raise ValueError(f"Missing test preds for {m}.")

X_meta_test = np.concatenate(test_preds_list, axis=1) # (N_Test, 32)

print(f"Meta-Test Input Shape:  {X_meta_test.shape}")


# train
def get_meta_learner(input_dim, n_classes):
    inputs = layers.Input(shape=(input_dim,))
    
    # Small MLP
    x = layers.Dense(64, activation='relu')(inputs)
    x = layers.Dropout(0.5)(x) 
    x = layers.Dense(32, activation='relu')(x)
    
    outputs = layers.Dense(n_classes, activation='softmax')(x)
    return models.Model(inputs=inputs, outputs=outputs, name="Meta_Learner")

meta_model = get_meta_learner(X_meta_train.shape[1], n_classes)
meta_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

print("\nTraining Meta-Learner on Validation Set...")

history = meta_model.fit(
    X_meta_train, y_val_true,
    epochs=50,
    batch_size=16,
    validation_split=0.1, # Use 10% of Val set to check for overfitting
    callbacks=[callbacks.EarlyStopping(patience=5, restore_best_weights=True)],
    verbose=1
)

# Final evaluation on test set
meta_probs = meta_model.predict(X_meta_test)
y_pred_meta = np.argmax(meta_probs, axis=1)

# Metrics
acc_meta = accuracy_score(y_true_flat, y_pred_meta)
auc_meta = roc_auc_score(y_true_cat, meta_probs, multi_class='ovr')

print(f"\n>>> Final Stacking Results (Full Test Set):")
print(f"Stacking Accuracy: {acc_meta:.4f}")
print(f"Stacking AUC:      {auc_meta:.4f}")
print("-" * 30)

# Calculate Reference Soft Voting (for comparison)
X_test_reshaped = X_meta_test.reshape(-1, len(MODELS_TO_LOAD), n_classes) 
soft_vote_probs = np.mean(X_test_reshaped, axis=1)
acc_soft = accuracy_score(y_true_flat, np.argmax(soft_vote_probs, axis=1))

print(f"Reference Soft Voting: {acc_soft:.4f}")

fig, axes = plt.subplots(1, 3, figsize=(20, 5))

# Confusion Matrix
cm = confusion_matrix(y_true_flat, y_pred_meta)
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', ax=axes[0])
axes[0].set_title(f'Stacking Confusion Matrix (Acc: {acc_meta:.2%})')
axes[0].set_ylabel('True'); axes[0].set_xlabel('Predicted')

# Uncertainty
entropy = -np.sum(meta_probs * np.log(meta_probs + 1e-9), axis=1)
correct_mask = (y_pred_meta == y_true_flat)
sns.kdeplot(entropy[correct_mask], label='Correct', fill=True, color='green', ax=axes[1])
sns.kdeplot(entropy[~correct_mask], label='Wrong', fill=True, color='red', ax=axes[1])
axes[1].set_title('Stacking Uncertainty')
axes[1].legend()

# Calibration
is_correct = (y_pred_meta == y_true_flat).astype(int)
pred_conf = np.max(meta_probs, axis=1)
prob_true, prob_pred = calibration_curve(is_correct, pred_conf, n_bins=10, strategy='quantile')
axes[2].plot(prob_pred, prob_true, marker='o', label='Meta-Learner', color='darkgreen')
axes[2].plot([0, 1], [0, 1], linestyle='--', color='gray')
axes[2].set_title('Reliability Diagram')
axes[2].legend()

plt.tight_layout()
plt.show()
# Out:
# ==============================
# RIGOROUS STACKING (No Data Leakage)
# ==============================
# Loading VALIDATION predictions (Meta-Train)...
# Meta-Train Input Shape: (1003, 28)
# Loading TEST predictions (Meta-Eval)...
# Meta-Test Input Shape:  (2005, 28)
#
# Training Meta-Learner on Validation Set...
# Epoch 1/50
# 57/57 [==============================] - 2s 6ms/step - loss: 1.4193 - accuracy: 0.6275 - val_loss: 0.7667 - val_accuracy: 0.7921
# Epoch 2/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6560 - accuracy: 0.8038 - val_loss: 0.4767 - val_accuracy: 0.8515
# Epoch 3/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4712 - accuracy: 0.8825 - val_loss: 0.3955 - val_accuracy: 0.8812
# Epoch 4/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4099 - accuracy: 0.8869 - val_loss: 0.3369 - val_accuracy: 0.8911
# Epoch 5/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3886 - accuracy: 0.8925 - val_loss: 0.3204 - val_accuracy: 0.9010
# Epoch 6/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3658 - accuracy: 0.9002 - val_loss: 0.2990 - val_accuracy: 0.9010
# Epoch 7/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3479 - accuracy: 0.9113 - val_loss: 0.3050 - val_accuracy: 0.9010
# Epoch 8/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3378 - accuracy: 0.9180 - val_loss: 0.2969 - val_accuracy: 0.9010
# Epoch 9/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3202 - accuracy: 0.9146 - val_loss: 0.2957 - val_accuracy: 0.9010
# Epoch 10/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3232 - accuracy: 0.9080 - val_loss: 0.2830 - val_accuracy: 0.9010
# Epoch 11/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3237 - accuracy: 0.9224 - val_loss: 0.2802 - val_accuracy: 0.9010
# Epoch 12/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3083 - accuracy: 0.9102 - val_loss: 0.2757 - val_accuracy: 0.9010
# Epoch 13/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3139 - accuracy: 0.9191 - val_loss: 0.2903 - val_accuracy: 0.9010
# Epoch 14/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3112 - accuracy: 0.9157 - val_loss: 0.2877 - val_accuracy: 0.9010
# Epoch 15/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2921 - accuracy: 0.9135 - val_loss: 0.2829 - val_accuracy: 0.9010
# Epoch 16/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2973 - accuracy: 0.9213 - val_loss: 0.2849 - val_accuracy: 0.9010
# Epoch 17/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2854 - accuracy: 0.9213 - val_loss: 0.2799 - val_accuracy: 0.9109
# 63/63 [==============================] - 0s 1ms/step
#
# >>> Final Stacking Results (Full Test Set):
# Stacking Accuracy: 0.9177
# Stacking AUC:      0.9790
# ------------------------------
# Reference Soft Voting: 0.9197
