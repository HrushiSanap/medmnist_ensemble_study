# %% [markdown]
# ## Install and Imports

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"

# !pip install -q medmnist transformers tf-keras

import medmnist
from medmnist import INFO
import numpy as np
import os
import gc
import tensorflow as tf
from tensorflow.keras import layers, models, applications, mixed_precision
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from transformers import TFViTForImageClassification, TFSwinForImageClassification
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score, log_loss
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 4.3 MB/s eta 0:00:00
# 2026-02-12 15:14:11.078392: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770909251.277424      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770909251.339925      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770909251.825188      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770909251.825241      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770909251.825244      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770909251.825246      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
print(f"Legacy Keras Enabled: {str(os.environ.get('TF_USE_LEGACY_KERAS'))}")
# Out:
# Legacy Keras Enabled: 1

# %%
# CONFIGURATION 
DATASET = 'organamnist'
BATCH_SIZE = 32
EPOCHS = 15

# %%
# MIXED PRECISION SETUP 
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
print(f"Policy: {policy.name} | Compute: {policy.compute_dtype}")
# Out:
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   Tesla P100-PCIE-16GB, compute capability 6.0
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once
# Policy: mixed_float16 | Compute: float16

# %% [markdown]
# ## Data Loader Function

# %%
def load_medmnist_data(dataset_flag, resize_target=224, batch_size=32):
    info = INFO[dataset_flag]
    n_classes = len(info['label'])
    DataClass = getattr(medmnist, info['python_class'])

    print(f"Loading {dataset_flag} (Lazy Loading Mode)...")
    
    # 1. Download/Load raw data as small 28x28 images (Keeps RAM usage low)
    # We use 'size=28' here to prevent the RAM explosion
    train_data = DataClass(split='train', download=True, size=28)
    val_data = DataClass(split='val', download=True, size=28)
    test_data = DataClass(split='test', download=True, size=28)

    X_train, y_train = train_data.imgs, train_data.labels
    X_val, y_val = val_data.imgs, val_data.labels
    X_test, y_test = test_data.imgs, test_data.labels

    def preprocess_pipeline(image, label):
        if len(image.shape) == 2:
            image = tf.expand_dims(image, axis=-1)
            
        if image.shape[-1] == 1:
            image = tf.image.grayscale_to_rgb(image)
            
        image = tf.image.resize(image, [resize_target, resize_target])
        
        image = tf.cast(image, tf.float32)
        
        label = tf.one_hot(label, n_classes)
        label = tf.squeeze(label) 
        return image, label

    train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    train_ds = train_ds.map(preprocess_pipeline, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.shuffle(1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

    val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))
    val_ds = val_ds.map(preprocess_pipeline, num_parallel_calls=tf.data.AUTOTUNE)
    val_ds = val_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))
    test_ds = test_ds.map(preprocess_pipeline, num_parallel_calls=tf.data.AUTOTUNE)
    test_ds = test_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return train_ds, val_ds, test_ds, n_classes, y_test

# %% [markdown]
# ## Model Loader Function

# %%
# Function: Model Loader 
def get_model(model_name, n_classes, input_shape=(224, 224, 3)):
    inputs = layers.Input(shape=input_shape)
    
    if model_name == 'EfficientNetV2M':
        base = applications.EfficientNetV2M(include_top=False, weights='imagenet', input_tensor=inputs)
        x = layers.GlobalAveragePooling2D()(base.output)
        # Force float32 for stability in final layer
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)
        return models.Model(inputs=inputs, outputs=outputs, name=model_name)

    elif model_name == 'InceptionResNetV2':
        x = layers.Rescaling(1./127.5, offset=-1)(inputs)
        base = applications.InceptionResNetV2(include_top=False, weights='imagenet', input_tensor=x)
        x = layers.GlobalAveragePooling2D()(base.output)
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)
        return models.Model(inputs=inputs, outputs=outputs, name=model_name)

    elif model_name == 'ConvNeXtBase':
        base = applications.ConvNeXtBase(include_top=False, weights='imagenet', input_tensor=inputs)
        x = layers.GlobalAveragePooling2D()(base.output)
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)
        return models.Model(inputs=inputs, outputs=outputs, name=model_name)

    elif model_name == 'ViT-Base':
        x = layers.Rescaling(1./127.5, offset=-1)(inputs)
        x = layers.Permute((3, 1, 2))(x)
        backbone = TFViTForImageClassification.from_pretrained(
            'google/vit-base-patch16-224', num_labels=n_classes, 
            ignore_mismatched_sizes=True, use_safetensors=False)
        outputs = backbone.vit(x)[0]
        outputs = backbone.classifier(outputs[:, 0, :])
        outputs = layers.Activation('softmax', dtype='float32')(outputs)
        return models.Model(inputs=inputs, outputs=outputs, name=model_name)

    else:
        raise ValueError("Unknown Model")

# %% [markdown]
# ## Trainer Function

# %%
# Function: Model Trainer
def train_and_save(model_name):
    print(f"\n{'='*20} TRAINING {model_name} {'='*20}")
    tf.keras.backend.clear_session()
    gc.collect()
    
    if os.path.exists(f"{model_name}_{DATASET}.keras"):
        print(f"Found existing model: {model_name}_{DATASET}.keras. Loading weights...")
        model = get_model(model_name, n_classes)
        model.load_weights(f"{model_name}_{DATASET}.keras")
        
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    else:
        # Train from scratch
        model = get_model(model_name, n_classes)
        lr = 2e-5 if model_name in ['ViT-Base'] else 1e-4
        model.compile(optimizer=tf.keras.optimizers.Adam(lr), 
                      loss='categorical_crossentropy', metrics=['accuracy'])
        
        callbacks = [
            ModelCheckpoint(f"{model_name}_{DATASET}.keras", save_best_only=True, monitor='val_accuracy', mode='max', verbose=1),
            ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1),
            EarlyStopping(monitor='val_accuracy', patience=7, restore_best_weights=True, verbose=1)
        ]
        model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS, callbacks=callbacks, verbose=1)
        # Load best weights
        model.load_weights(f"{model_name}_{DATASET}.keras")

    # Generate Predictions
    print(f"Generating predictions for {model_name}...")
    
    # Validation Set
    val_preds = model.predict(val_ds)
    np.save(f"{model_name}_val_preds.npy", val_preds)
    
    # Test Set
    test_preds = model.predict(test_ds)
    np.save(f"{model_name}_preds.npy", test_preds)
    
    # Test Accuracy
    acc = accuracy_score(y_true_flat, np.argmax(test_preds, axis=1))
    print(f"{model_name} Test Accuracy: {acc:.4f}")
    
    del model
    gc.collect()
    return acc

# %%
# Load Data
train_ds, val_ds, test_ds, n_classes, y_test_true = load_medmnist_data(DATASET, resize_target=224, batch_size=BATCH_SIZE)

y_true_flat = y_test_true.flatten()
y_true_cat = to_categorical(y_true_flat, n_classes)
print(f"Data Ready. Classes: {n_classes}")
# Out:
# Loading organamnist (Lazy Loading Mode)...
# 100%|██████████| 38.2M/38.2M [00:02<00:00, 14.4MB/s]
# I0000 00:00:1770909275.783495      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Data Ready. Classes: 11

# %% [markdown]
# ## Training

# %%
train_and_save('ViT-Base')
# Out:
# ==================== TRAINING ViT-Base ====================
# config.json: 0.00B [00:00, ?B/s]
# tf_model.h5:   0%|          | 0.00/347M [00:00<?, ?B/s]
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# All model checkpoint layers were used when initializing TFViTForImageClassification.
#
# Some weights of TFViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier/kernel:0: found shape (768, 1000) in the checkpoint and (768, 11) in the model instantiated
# - classifier/bias:0: found shape (1000,) in the checkpoint and (11,) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/15
# I0000 00:00:1770909315.628555     127 cuda_dnn.cc:529] Loaded cuDNN version 91002
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1770909318.244816     128 service.cc:152] XLA service 0x7955a56a9550 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1770909318.244854     128 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1770909318.646317     128 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1081/1081 [==============================] - ETA: 0s - loss: 0.1815 - accuracy: 0.9505
# Epoch 1: val_accuracy improved from -inf to 0.98721, saving model to ViT-Base_organamnist.keras
# 1081/1081 [==============================] - 869s 755ms/step - loss: 0.1815 - accuracy: 0.9505 - val_loss: 0.0356 - val_accuracy: 0.9872 - lr: 2.0000e-05
# Epoch 2/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9958
# Epoch 2: val_accuracy improved from 0.98721 to 0.99122, saving model to ViT-Base_organamnist.keras
# 1081/1081 [==============================] - 814s 752ms/step - loss: 0.0161 - accuracy: 0.9958 - val_loss: 0.0258 - val_accuracy: 0.9912 - lr: 2.0000e-05
# Epoch 3/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9986
# Epoch 3: val_accuracy did not improve from 0.99122
# 1081/1081 [==============================] - 806s 745ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0553 - val_accuracy: 0.9829 - lr: 2.0000e-05
# Epoch 4/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9981
# Epoch 4: val_accuracy did not improve from 0.99122
# 1081/1081 [==============================] - 806s 745ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.0465 - val_accuracy: 0.9840 - lr: 2.0000e-05
# Epoch 5/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9992
# Epoch 5: val_accuracy improved from 0.99122 to 0.99384, saving model to ViT-Base_organamnist.keras
# 1081/1081 [==============================] - 812s 751ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.0158 - val_accuracy: 0.9938 - lr: 2.0000e-05
# Epoch 6/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9976
# Epoch 6: val_accuracy did not improve from 0.99384
# 1081/1081 [==============================] - 806s 746ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.0348 - val_accuracy: 0.9884 - lr: 2.0000e-05
# Epoch 7/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9997
# Epoch 7: val_accuracy did not improve from 0.99384
# 1081/1081 [==============================] - 807s 746ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0354 - val_accuracy: 0.9894 - lr: 2.0000e-05
# Epoch 8/15
# 1081/1081 [==============================] - ETA: 0s - loss: 1.4303e-04 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.99384
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 1081/1081 [==============================] - 806s 746ms/step - loss: 1.4303e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9888 - lr: 2.0000e-05
# Epoch 9/15
# 1081/1081 [==============================] - ETA: 0s - loss: 9.3576e-05 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.99384
# 1081/1081 [==============================] - 807s 746ms/step - loss: 9.3576e-05 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9877 - lr: 1.0000e-05
# Epoch 10/15
# 1081/1081 [==============================] - ETA: 0s - loss: 6.8075e-05 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.99384
# 1081/1081 [==============================] - 807s 746ms/step - loss: 6.8075e-05 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9877 - lr: 1.0000e-05
# Epoch 11/15
# 1081/1081 [==============================] - ETA: 0s - loss: 4.7901e-05 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.99384
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 1081/1081 [==============================] - 806s 746ms/step - loss: 4.7901e-05 - accuracy: 1.0000 - val_loss: 0.0470 - val_accuracy: 0.9878 - lr: 1.0000e-05
# Epoch 12/15
# 1081/1081 [==============================] - ETA: 0s - loss: 3.6094e-05 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.99384
# 1081/1081 [==============================] - 806s 746ms/step - loss: 3.6094e-05 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 0.9880 - lr: 5.0000e-06
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Generating predictions for ViT-Base...
# 203/203 [==============================] - 52s 240ms/step
# 556/556 [==============================] - 134s 240ms/step
# ViT-Base Test Accuracy: 0.9626
# 0.9625942175722804

# %%
train_and_save('ConvNeXtBase')
# Out:
# ==================== TRAINING ConvNeXtBase ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 [==============================] - 5s 0us/step
# Epoch 1/15
# 2026-02-12 18:01:58.512929: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 18:01:58.720792: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 18:01:58.935322: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 18:01:59.120649: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.9675
# Epoch 1: val_accuracy improved from -inf to 0.98675, saving model to ConvNeXtBase_organamnist.keras
# 1081/1081 [==============================] - 1293s 1s/step - loss: 0.0975 - accuracy: 0.9675 - val_loss: 0.0595 - val_accuracy: 0.9868 - lr: 1.0000e-04
# Epoch 2/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9942
# Epoch 2: val_accuracy did not improve from 0.98675
# 1081/1081 [==============================] - 987s 913ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0435 - val_accuracy: 0.9858 - lr: 1.0000e-04
# Epoch 3/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9972
# Epoch 3: val_accuracy improved from 0.98675 to 0.98906, saving model to ConvNeXtBase_organamnist.keras
# 1081/1081 [==============================] - 994s 919ms/step - loss: 0.0104 - accuracy: 0.9972 - val_loss: 0.0322 - val_accuracy: 0.9891 - lr: 1.0000e-04
# Epoch 4/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9962
# Epoch 4: val_accuracy did not improve from 0.98906
# 1081/1081 [==============================] - 986s 912ms/step - loss: 0.0131 - accuracy: 0.9962 - val_loss: 0.0658 - val_accuracy: 0.9871 - lr: 1.0000e-04
# Epoch 5/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9976
# Epoch 5: val_accuracy improved from 0.98906 to 0.99384, saving model to ConvNeXtBase_organamnist.keras
# 1081/1081 [==============================] - 994s 919ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0154 - val_accuracy: 0.9938 - lr: 1.0000e-04
# Epoch 6/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9975
# Epoch 6: val_accuracy did not improve from 0.99384
# 1081/1081 [==============================] - 986s 912ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.0324 - val_accuracy: 0.9903 - lr: 1.0000e-04
# Epoch 7/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9973
# Epoch 7: val_accuracy did not improve from 0.99384
# 1081/1081 [==============================] - 987s 913ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.0473 - val_accuracy: 0.9898 - lr: 1.0000e-04
# Epoch 8/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9980
# Epoch 8: val_accuracy did not improve from 0.99384
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1081/1081 [==============================] - 986s 912ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.0194 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 9/15
# 1081/1081 [==============================] - ETA: 0s - loss: 5.2948e-05 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.99384
# 1081/1081 [==============================] - 987s 913ms/step - loss: 5.2948e-05 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 0.9931 - lr: 5.0000e-05
# Epoch 11/15
# 1081/1081 [==============================] - ETA: 0s - loss: 1.5442e-05 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.99384
# 1081/1081 [==============================] - 988s 913ms/step - loss: 1.5442e-05 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9938 - lr: 5.0000e-05
# Epoch 12/15
# 1081/1081 [==============================] - ETA: 0s - loss: 8.0791e-06 - accuracy: 1.0000
# Epoch 12: val_accuracy improved from 0.99384 to 0.99415, saving model to ConvNeXtBase_organamnist.keras
# 1081/1081 [==============================] - 994s 920ms/step - loss: 8.0791e-06 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9941 - lr: 5.0000e-05
# Epoch 13/15
# 1081/1081 [==============================] - ETA: 0s - loss: 4.6437e-06 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.99415
# 1081/1081 [==============================] - 987s 913ms/step - loss: 4.6437e-06 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9938 - lr: 5.0000e-05
# Epoch 14/15
# 1081/1081 [==============================] - ETA: 0s - loss: 2.7057e-06 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.99415
# 1081/1081 [==============================] - 986s 912ms/step - loss: 2.7057e-06 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 0.9935 - lr: 5.0000e-05
# Epoch 15/15
# 1081/1081 [==============================] - ETA: 0s - loss: 1.5795e-06 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.99415
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 1081/1081 [==============================] - 986s 911ms/step - loss: 1.5795e-06 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9934 - lr: 5.0000e-05
# Restoring model weights from the end of the best epoch: 12.
# Generating predictions for ConvNeXtBase...
# 203/203 [==============================] - 62s 289ms/step
# 556/556 [==============================] - 189s 340ms/step
# ConvNeXtBase Test Accuracy: 0.9750
# 0.9750253121835977

# %%
train_and_save('EfficientNetV2M')
# Out:
# ==================== TRAINING EfficientNetV2M ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 1s 0us/step
# Epoch 1/15
# E0000 00:00:1770934707.510492      55 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inEfficientNetV2M/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1081/1081 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.9466
# Epoch 1: val_accuracy improved from -inf to 0.98336, saving model to EfficientNetV2M_organamnist.keras
# 1081/1081 [==============================] - 806s 636ms/step - loss: 0.1704 - accuracy: 0.9466 - val_loss: 0.0660 - val_accuracy: 0.9834 - lr: 1.0000e-04
# Epoch 2/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9923
# Epoch 2: val_accuracy improved from 0.98336 to 0.98536, saving model to EfficientNetV2M_organamnist.keras
# 1081/1081 [==============================] - 570s 527ms/step - loss: 0.0257 - accuracy: 0.9923 - val_loss: 0.0437 - val_accuracy: 0.9854 - lr: 1.0000e-04
# Epoch 3/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9941
# Epoch 3: val_accuracy improved from 0.98536 to 0.98768, saving model to EfficientNetV2M_organamnist.keras
# 1081/1081 [==============================] - 568s 525ms/step - loss: 0.0196 - accuracy: 0.9941 - val_loss: 0.0348 - val_accuracy: 0.9877 - lr: 1.0000e-04
# Epoch 4/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9958
# Epoch 4: val_accuracy did not improve from 0.98768
# 1081/1081 [==============================] - 561s 519ms/step - loss: 0.0143 - accuracy: 0.9958 - val_loss: 0.0412 - val_accuracy: 0.9858 - lr: 1.0000e-04
# Epoch 5/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9961
# Epoch 5: val_accuracy did not improve from 0.98768
# 1081/1081 [==============================] - 561s 519ms/step - loss: 0.0134 - accuracy: 0.9961 - val_loss: 0.0694 - val_accuracy: 0.9803 - lr: 1.0000e-04
# Epoch 6/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9967
# Epoch 6: val_accuracy did not improve from 0.98768
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1081/1081 [==============================] - 560s 518ms/step - loss: 0.0114 - accuracy: 0.9967 - val_loss: 0.0754 - val_accuracy: 0.9827 - lr: 1.0000e-04
# Epoch 7/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9992
# Epoch 7: val_accuracy did not improve from 0.98768
# 1081/1081 [==============================] - 560s 518ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0348 - val_accuracy: 0.9874 - lr: 5.0000e-05
# Epoch 8/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9995
# Epoch 8: val_accuracy improved from 0.98768 to 0.99060, saving model to EfficientNetV2M_organamnist.keras
# 1081/1081 [==============================] - 568s 525ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0263 - val_accuracy: 0.9906 - lr: 5.0000e-05
# Epoch 9/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992
# Epoch 9: val_accuracy did not improve from 0.99060
# 1081/1081 [==============================] - 561s 519ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0295 - val_accuracy: 0.9894 - lr: 5.0000e-05
# Epoch 10/15
#  214/1081 [====>.........................] - ETA: 7:11 - loss: 0.0123 - accuracy: 0.9968
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=10000.0 (msgs/sec)
# ServerApp.rate_limit_window=1.0 (secs)

# %%
train_and_save('InceptionResNetV2')
# Out:
# ==================== TRAINING InceptionResNetV2 ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 1s 0us/step
# Epoch 1/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9440
# Epoch 1: val_accuracy improved from -inf to 0.98043, saving model to InceptionResNetV2_organamnist.keras
# 1081/1081 [==============================] - 584s 399ms/step - loss: 0.1676 - accuracy: 0.9440 - val_loss: 0.1453 - val_accuracy: 0.9804 - lr: 1.0000e-04
# Epoch 2/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9915
# Epoch 2: val_accuracy did not improve from 0.98043
# 1081/1081 [==============================] - 384s 355ms/step - loss: 0.0264 - accuracy: 0.9915 - val_loss: 0.5799 - val_accuracy: 0.7931 - lr: 1.0000e-04
# Epoch 3/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9946
# Epoch 3: val_accuracy improved from 0.98043 to 0.98090, saving model to InceptionResNetV2_organamnist.keras
# 1081/1081 [==============================] - 389s 360ms/step - loss: 0.0185 - accuracy: 0.9946 - val_loss: 0.0583 - val_accuracy: 0.9809 - lr: 1.0000e-04
# Epoch 4/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9951
# Epoch 4: val_accuracy did not improve from 0.98090
# 1081/1081 [==============================] - 382s 353ms/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 8.2795 - val_accuracy: 0.9428 - lr: 1.0000e-04
# Epoch 5/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9961
# Epoch 5: val_accuracy improved from 0.98090 to 0.98906, saving model to InceptionResNetV2_organamnist.keras
# 1081/1081 [==============================] - 388s 359ms/step - loss: 0.0124 - accuracy: 0.9961 - val_loss: 0.0358 - val_accuracy: 0.9891 - lr: 1.0000e-04
# Epoch 6/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9964
# Epoch 6: val_accuracy did not improve from 0.98906
# 1081/1081 [==============================] - 382s 353ms/step - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.0333 - val_accuracy: 0.9886 - lr: 1.0000e-04
# Epoch 7/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9966
# Epoch 7: val_accuracy did not improve from 0.98906
# 1081/1081 [==============================] - 382s 353ms/step - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.0498 - val_accuracy: 0.9864 - lr: 1.0000e-04
# Epoch 8/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9968
# Epoch 8: val_accuracy did not improve from 0.98906
# 1081/1081 [==============================] - 382s 353ms/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 0.0510 - val_accuracy: 0.9880 - lr: 1.0000e-04
# Epoch 9/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9972
# Epoch 9: val_accuracy improved from 0.98906 to 0.98922, saving model to InceptionResNetV2_organamnist.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1081/1081 [==============================] - 388s 359ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.0457 - val_accuracy: 0.9892 - lr: 1.0000e-04
# Epoch 10/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9994
# Epoch 10: val_accuracy improved from 0.98922 to 0.98952, saving model to InceptionResNetV2_organamnist.keras
# 1081/1081 [==============================] - 389s 360ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0352 - val_accuracy: 0.9895 - lr: 5.0000e-05
# Epoch 11/15
# 1081/1081 [==============================] - ETA: 0s - loss: 7.4184e-04 - accuracy: 0.9997
# Epoch 11: val_accuracy did not improve from 0.98952
# 1081/1081 [==============================] - 381s 353ms/step - loss: 7.4184e-04 - accuracy: 0.9997 - val_loss: 0.0486 - val_accuracy: 0.9866 - lr: 5.0000e-05
# Epoch 12/15
# 1081/1081 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992
# Epoch 12: val_accuracy did not improve from 0.98952
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 1081/1081 [==============================] - 382s 354ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0926 - val_accuracy: 0.9823 - lr: 5.0000e-05
# Epoch 13/15
# 1081/1081 [==============================] - ETA: 0s - loss: 9.3252e-04 - accuracy: 0.9997
# Epoch 13: val_accuracy did not improve from 0.98952
# 1081/1081 [==============================] - 383s 354ms/step - loss: 9.3252e-04 - accuracy: 0.9997 - val_loss: 0.0955 - val_accuracy: 0.9821 - lr: 2.5000e-05
# Epoch 14/15
# 1081/1081 [==============================] - ETA: 0s - loss: 2.5637e-04 - accuracy: 0.9999
# Epoch 14: val_accuracy did not improve from 0.98952
# 1081/1081 [==============================] - 382s 353ms/step - loss: 2.5637e-04 - accuracy: 0.9999 - val_loss: 0.0709 - val_accuracy: 0.9846 - lr: 2.5000e-05
# Epoch 15/15
# 1081/1081 [==============================] - ETA: 0s - loss: 5.5117e-04 - accuracy: 0.9998
# Epoch 15: val_accuracy improved from 0.98952 to 0.99122, saving model to InceptionResNetV2_organamnist.keras
# 1081/1081 [==============================] - 389s 360ms/step - loss: 5.5117e-04 - accuracy: 0.9998 - val_loss: 0.0307 - val_accuracy: 0.9912 - lr: 2.5000e-05
# Restoring model weights from the end of the best epoch: 15.
# Generating predictions for InceptionResNetV2...
# 203/203 [==============================] - 22s 93ms/step
# 556/556 [==============================] - 53s 95ms/step
# InceptionResNetV2 Test Accuracy: 0.9590
# 0.9589942625717178

# %% [markdown]
# ## Ensemble (Soft Voting) & Results

# %%
# ENSEMBLE ANALYSIS 
print(f"\n{'='*30}\nENSEMBLE EXECUTION\n{'='*30}")

MODELS_TO_LOAD = ['ConvNeXtBase', 'ViT-Base', 'EfficientNetV2M', 'InceptionResNetV2']
loaded_preds = []
valid_models = []

for m in MODELS_TO_LOAD:
    filename = f"{m}_preds.npy"
    if os.path.exists(filename):
        print(f"Loading {filename}...")
        loaded_preds.append(np.load(filename))
        valid_models.append(m)
    else:
        print(f"Warning: {filename} not found. Skipping.")

if not loaded_preds:
    raise ValueError("No predictions found! Train at least one model first.")

# Stack and Average
all_preds = np.array(loaded_preds) # Shape: (Num_Models, N_Samples, N_Classes)
ensemble_probs = np.mean(all_preds, axis=0)

y_pred_ensemble = np.argmax(ensemble_probs, axis=1)

# Metrics
print("\n>>> Classification Report:")
print(classification_report(y_true_flat, y_pred_ensemble))

ens_acc = accuracy_score(y_true_flat, y_pred_ensemble)
ens_auc = roc_auc_score(y_true_cat, ensemble_probs, multi_class='ovr')
ens_loss = log_loss(y_true_cat, ensemble_probs)

print(f"Ensemble Accuracy: {ens_acc:.4f}")
print(f"Ensemble AUC:      {ens_auc:.4f}")

fig, axes = plt.subplots(1, 3, figsize=(20, 5))

# Confusion Matrix
cm = confusion_matrix(y_true_flat, y_pred_ensemble)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title(f'Ensemble Confusion Matrix (Acc: {ens_acc:.2%})')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('True')

# Uncertainty (Entropy)
entropy = -np.sum(ensemble_probs * np.log(ensemble_probs + 1e-9), axis=1)
correct_mask = (y_pred_ensemble == y_true_flat)

sns.kdeplot(entropy[correct_mask], label='Correct', fill=True, color='green', ax=axes[1])
sns.kdeplot(entropy[~correct_mask], label='Wrong', fill=True, color='red', ax=axes[1])
axes[1].set_title('Uncertainty (Entropy) Distribution')
axes[1].legend()

# Calibration (Top-Class)
is_correct = (y_pred_ensemble == y_true_flat).astype(int)
pred_confidence = np.max(ensemble_probs, axis=1)
prob_true, prob_pred = calibration_curve(is_correct, pred_confidence, n_bins=10, strategy='quantile')

axes[2].plot(prob_pred, prob_true, marker='o', label='Ensemble', color='purple')
axes[2].plot([0, 1], [0, 1], linestyle='--', color='gray', label='Perfect')
axes[2].set_title('Reliability Diagram')
axes[2].set_xlabel('Confidence')
axes[2].set_ylabel('Accuracy')
axes[2].legend()
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ==============================
# ENSEMBLE EXECUTION
# ==============================
# Loading ConvNeXtBase_preds.npy...
# Loading ViT-Base_preds.npy...
# Loading EfficientNetV2M_preds.npy...
# Loading InceptionResNetV2_preds.npy...
#
# >>> Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      1036
#            1       0.99      0.98      0.99       784
#            2       0.99      0.99      0.99       793
#            3       1.00      0.94      0.97       785
#            4       0.94      0.91      0.92      2064
#            5       0.98      0.97      0.98      1965
#            6       1.00      0.99      1.00      3285
#            7       0.98      1.00      0.99      1747
#            8       0.99      1.00      0.99      1813
#            9       0.97      0.97      0.97      1622
#           10       0.94      0.99      0.96      1884
#
#     accuracy                           0.98     17778
#    macro avg       0.98      0.98      0.98     17778
# weighted avg       0.98      0.98      0.98     17778
#
# Ensemble Accuracy: 0.9756
# Ensemble AUC:      0.9994

# %% [markdown]
# ## Individual Model Results

# %%
MODELS_TO_LOAD = ['ConvNeXtBase', 'ViT-Base', 'EfficientNetV2M', 'InceptionResNetV2']

print(f"\n{'='*50}\nINDIVIDUAL MODEL DIAGNOSTICS\n{'='*50}")

model_scores = {}

for model_name in MODELS_TO_LOAD:
    filename = f"{model_name}_preds.npy"
    
    if not os.path.exists(filename):
        print(f"Warning: {filename} not found. Skipping.")
        continue

    # Load Predictions
    preds_probs = np.load(filename)
    y_pred = np.argmax(preds_probs, axis=1)

    # Calculate Metrics
    acc = accuracy_score(y_true_flat, y_pred)
    auc = roc_auc_score(y_true_cat, preds_probs, multi_class='ovr')
    model_scores[model_name] = acc

    print(f"\n{'='*20} {model_name} {'='*20}")
    print(f"Accuracy: {acc:.4%}")
    print(f"AUC:      {auc:.4f}")
    print("-" * 60)
    print(classification_report(y_true_flat, y_pred))

    # Plotting Suite
    fig, axes = plt.subplots(1, 3, figsize=(20, 5))

    # Confusion Matrix
    cm = confusion_matrix(y_true_flat, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', ax=axes[0])
    axes[0].set_title(f'{model_name} Confusion Matrix')
    axes[0].set_xlabel('Predicted Label')
    axes[0].set_ylabel('True Label')

    # Uncertainty (Entropy) Distribution
    entropy = -np.sum(preds_probs * np.log(preds_probs + 1e-9), axis=1)
    correct_mask = (y_pred == y_true_flat)
    
    sns.kdeplot(entropy[correct_mask], label='Correct', fill=True, color='green', ax=axes[1])
    sns.kdeplot(entropy[~correct_mask], label='Wrong', fill=True, color='red', ax=axes[1])
    axes[1].set_title(f'{model_name} Uncertainty Profile')
    axes[1].set_xlabel('Entropy (Uncertainty)')
    axes[1].legend()

    # Reliability Diagram (Calibration)
    is_correct = (y_pred == y_true_flat).astype(int)
    pred_conf = np.max(preds_probs, axis=1)
    prob_true, prob_pred = calibration_curve(is_correct, pred_conf, n_bins=10, strategy='quantile')
    
    axes[2].plot(prob_pred, prob_true, marker='o', label=model_name, color='darkorange')
    axes[2].plot([0, 1], [0, 1], linestyle='--', color='gray', label='Perfect')
    axes[2].set_title(f'{model_name} Reliability')
    axes[2].set_xlabel('Confidence')
    axes[2].set_ylabel('Accuracy')
    axes[2].legend()
    axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# Summary Comparison Table
print("\n" + "="*30)
print("FINAL PERFORMANCE SUMMARY")
print("="*30)
print(f"{'Model Name':<20} | {'Accuracy':<10}")
print("-" * 35)
for name, score in model_scores.items():
    print(f"{name:<20} | {score:.4%}")
print("-" * 35)
# Out:
# ==================================================
# INDIVIDUAL MODEL DIAGNOSTICS
# ==================================================
#
# ==================== ConvNeXtBase ====================
# Accuracy: 97.5025%
# AUC:      0.9993
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1036
#            1       0.99      0.97      0.98       784
#            2       0.98      0.99      0.99       793
#            3       1.00      0.96      0.98       785
#            4       0.95      0.91      0.93      2064
#            5       0.98      0.97      0.98      1965
#            6       1.00      0.99      0.99      3285
#            7       0.99      1.00      0.99      1747
#            8       0.99      1.00      0.99      1813
#            9       0.95      0.97      0.96      1622
#           10       0.95      0.99      0.97      1884
#
#     accuracy                           0.98     17778
#    macro avg       0.98      0.97      0.97     17778
# weighted avg       0.98      0.98      0.97     17778
# ==================== ViT-Base ====================
# Accuracy: 96.2594%
# AUC:      0.9984
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      1036
#            1       0.98      0.95      0.96       784
#            2       0.96      0.98      0.97       793
#            3       0.98      0.87      0.93       785
#            4       0.92      0.88      0.90      2064
#            5       0.96      0.96      0.96      1965
#            6       0.99      1.00      1.00      3285
#            7       0.96      1.00      0.98      1747
#            8       1.00      1.00      1.00      1813
#            9       0.98      0.93      0.95      1622
#           10       0.92      0.98      0.95      1884
#
#     accuracy                           0.96     17778
#    macro avg       0.96      0.96      0.96     17778
# weighted avg       0.96      0.96      0.96     17778
# ==================== EfficientNetV2M ====================
# Accuracy: 96.7094%
# AUC:      0.9991
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      1036
#            1       0.95      0.98      0.96       784
#            2       0.99      0.96      0.98       793
#            3       1.00      0.95      0.98       785
#            4       0.91      0.90      0.90      2064
#            5       0.96      0.94      0.95      1965
#            6       1.00      0.99      1.00      3285
#            7       0.98      1.00      0.99      1747
#            8       0.99      1.00      0.99      1813
#            9       0.98      0.97      0.97      1622
#           10       0.94      0.97      0.95      1884
#
#     accuracy                           0.97     17778
#    macro avg       0.97      0.97      0.97     17778
# weighted avg       0.97      0.97      0.97     17778
# ==================== InceptionResNetV2 ====================
# Accuracy: 95.8994%
# AUC:      0.9980
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      1036
#            1       0.99      0.95      0.97       784
#            2       0.97      0.97      0.97       793
#            3       1.00      0.92      0.96       785
#            4       0.91      0.86      0.89      2064
#            5       0.97      0.94      0.95      1965
#            6       0.99      0.99      0.99      3285
#            7       0.97      1.00      0.99      1747
#            8       0.98      0.99      0.99      1813
#            9       0.96      0.96      0.96      1622
#           10       0.91      0.96      0.94      1884
#
#     accuracy                           0.96     17778
#    macro avg       0.96      0.96      0.96     17778
# weighted avg       0.96      0.96      0.96     17778
# ==============================
# FINAL PERFORMANCE SUMMARY
# ==============================
# Model Name           | Accuracy
# -----------------------------------
# ConvNeXtBase         | 97.5025%
# ViT-Base             | 96.2594%
# EfficientNetV2M      | 96.7094%
# InceptionResNetV2    | 95.8994%
# -----------------------------------

# %% [markdown]
# ## Stacking & Results

# %%
from tensorflow.keras import  callbacks 

print(f"\n{'='*30}\nRIGOROUS STACKING (No Data Leakage)\n{'='*30}")
MODELS_TO_LOAD = ['ConvNeXtBase', 'ViT-Base', 'EfficientNetV2M', 'InceptionResNetV2']

# training meta-data  (From Validation Set)
print("Loading VALIDATION predictions (Meta-Train)...")
val_preds_list = []
for m in MODELS_TO_LOAD:
    filename = f"{m}_val_preds.npy"
    if os.path.exists(filename):
        val_preds_list.append(np.load(filename))
    else:
        raise ValueError(f"Missing validation preds for {m}. Re-run training cell.")

X_meta_train = np.concatenate(val_preds_list, axis=1) # (N_Val, 32)

# labels for the validation set
y_val_true = np.concatenate([y for x, y in val_ds], axis=0)
y_val_flat = np.argmax(y_val_true, axis=1)

print(f"Meta-Train Input Shape: {X_meta_train.shape}")


# testing meta-data (From Test Set) 
print("Loading TEST predictions (Meta-Eval)...")
test_preds_list = []
for m in MODELS_TO_LOAD:
    filename = f"{m}_preds.npy"
    if os.path.exists(filename):
        test_preds_list.append(np.load(filename))
    else:
        raise ValueError(f"Missing test preds for {m}.")

X_meta_test = np.concatenate(test_preds_list, axis=1) # (N_Test, 32)

print(f"Meta-Test Input Shape:  {X_meta_test.shape}")


# train
def get_meta_learner(input_dim, n_classes):
    inputs = layers.Input(shape=(input_dim,))
    
    # Small MLP
    x = layers.Dense(64, activation='relu')(inputs)
    x = layers.Dropout(0.5)(x) 
    x = layers.Dense(32, activation='relu')(x)
    
    outputs = layers.Dense(n_classes, activation='softmax')(x)
    return models.Model(inputs=inputs, outputs=outputs, name="Meta_Learner")

meta_model = get_meta_learner(X_meta_train.shape[1], n_classes)
meta_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

print("\nTraining Meta-Learner on Validation Set...")

history = meta_model.fit(
    X_meta_train, y_val_true,
    epochs=50,
    batch_size=16,
    validation_split=0.1, # Use 10% of Val set to check for overfitting
    callbacks=[callbacks.EarlyStopping(patience=5, restore_best_weights=True)],
    verbose=1
)

# Final evaluation on test set
meta_probs = meta_model.predict(X_meta_test)
y_pred_meta = np.argmax(meta_probs, axis=1)

# Metrics
acc_meta = accuracy_score(y_true_flat, y_pred_meta)
auc_meta = roc_auc_score(y_true_cat, meta_probs, multi_class='ovr')

print(f"\n>>> Final Stacking Results (Full Test Set):")
print(f"Stacking Accuracy: {acc_meta:.4f}")
print(f"Stacking AUC:      {auc_meta:.4f}")
print("-" * 30)

# Calculate Reference Soft Voting (for comparison)
X_test_reshaped = X_meta_test.reshape(-1, len(MODELS_TO_LOAD), n_classes) 
soft_vote_probs = np.mean(X_test_reshaped, axis=1)
acc_soft = accuracy_score(y_true_flat, np.argmax(soft_vote_probs, axis=1))

print(f"Reference Soft Voting: {acc_soft:.4f}")

fig, axes = plt.subplots(1, 3, figsize=(20, 5))

# Confusion Matrix
cm = confusion_matrix(y_true_flat, y_pred_meta)
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', ax=axes[0])
axes[0].set_title(f'Stacking Confusion Matrix (Acc: {acc_meta:.2%})')
axes[0].set_ylabel('True'); axes[0].set_xlabel('Predicted')

# Uncertainty
entropy = -np.sum(meta_probs * np.log(meta_probs + 1e-9), axis=1)
correct_mask = (y_pred_meta == y_true_flat)
sns.kdeplot(entropy[correct_mask], label='Correct', fill=True, color='green', ax=axes[1])
sns.kdeplot(entropy[~correct_mask], label='Wrong', fill=True, color='red', ax=axes[1])
axes[1].set_title('Stacking Uncertainty')
axes[1].legend()

# Calibration
is_correct = (y_pred_meta == y_true_flat).astype(int)
pred_conf = np.max(meta_probs, axis=1)
prob_true, prob_pred = calibration_curve(is_correct, pred_conf, n_bins=10, strategy='quantile')
axes[2].plot(prob_pred, prob_true, marker='o', label='Meta-Learner', color='darkgreen')
axes[2].plot([0, 1], [0, 1], linestyle='--', color='gray')
axes[2].set_title('Reliability Diagram')
axes[2].legend()

plt.tight_layout()
plt.show()
# Out:
# ==============================
# RIGOROUS STACKING (No Data Leakage)
# ==============================
# Loading VALIDATION predictions (Meta-Train)...
# Meta-Train Input Shape: (6491, 44)
# Loading TEST predictions (Meta-Eval)...
# Meta-Test Input Shape:  (17778, 44)
#
# Training Meta-Learner on Validation Set...
# Epoch 1/50
# 366/366 [==============================] - 3s 4ms/step - loss: 0.6526 - accuracy: 0.8719 - val_loss: 0.0133 - val_accuracy: 0.9985
# Epoch 2/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0430 - accuracy: 0.9962 - val_loss: 0.0035 - val_accuracy: 0.9985
# Epoch 3/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0180 - accuracy: 0.9979 - val_loss: 7.2123e-04 - val_accuracy: 1.0000
# Epoch 4/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0145 - accuracy: 0.9978 - val_loss: 2.3618e-04 - val_accuracy: 1.0000
# Epoch 5/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0090 - accuracy: 0.9983 - val_loss: 9.9434e-05 - val_accuracy: 1.0000
# Epoch 6/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0099 - accuracy: 0.9986 - val_loss: 8.6697e-05 - val_accuracy: 1.0000
# Epoch 7/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0084 - accuracy: 0.9986 - val_loss: 4.8078e-05 - val_accuracy: 1.0000
# Epoch 8/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0054 - accuracy: 0.9991 - val_loss: 3.5112e-05 - val_accuracy: 1.0000
# Epoch 9/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0060 - accuracy: 0.9988 - val_loss: 6.2226e-05 - val_accuracy: 1.0000
# Epoch 10/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0052 - accuracy: 0.9993 - val_loss: 1.6664e-05 - val_accuracy: 1.0000
# Epoch 11/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 5.0168e-05 - val_accuracy: 1.0000
# Epoch 12/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 1.6609e-05 - val_accuracy: 1.0000
# Epoch 13/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0058 - accuracy: 0.9988 - val_loss: 1.8612e-04 - val_accuracy: 1.0000
# Epoch 14/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 1.9114e-05 - val_accuracy: 1.0000
# Epoch 15/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 4.3082e-06 - val_accuracy: 1.0000
# Epoch 16/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 7.6433e-06 - val_accuracy: 1.0000
# Epoch 17/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 1.2239e-05 - val_accuracy: 1.0000
# Epoch 18/50
# 366/366 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 9.5918e-06 - val_accuracy: 1.0000
# Epoch 19/50
# 366/366 [==============================] - 1s 3ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 1.5542e-05 - val_accuracy: 1.0000
# Epoch 20/50
# 366/366 [==============================] - 1s 3ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 8.2166e-06 - val_accuracy: 1.0000
# 556/556 [==============================] - 1s 1ms/step
#
# >>> Final Stacking Results (Full Test Set):
# Stacking Accuracy: 0.9752
# Stacking AUC:      0.9955
# ------------------------------
# Reference Soft Voting: 0.9756
# /tmp/ipykernel_55/1939179914.py:95: RuntimeWarning: divide by zero encountered in log
#   entropy = -np.sum(meta_probs * np.log(meta_probs + 1e-9), axis=1)
# /tmp/ipykernel_55/1939179914.py:95: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(meta_probs * np.log(meta_probs + 1e-9), axis=1)
