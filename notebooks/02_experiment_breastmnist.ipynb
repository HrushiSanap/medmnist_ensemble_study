# %% [markdown]
# ## Install and Imports

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"

# !pip install -q medmnist transformers tf-keras

import medmnist
from medmnist import INFO
import numpy as np
import os
import gc
import tensorflow as tf
from tensorflow.keras import layers, models, applications, mixed_precision
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from transformers import TFViTForImageClassification, TFSwinForImageClassification
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score, log_loss
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 9.0 MB/s eta 0:00:00
# 2026-02-12 04:02:28.502183: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770868948.675448     482 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770868948.725920     482 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770868949.149914     482 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770868949.149957     482 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770868949.149959     482 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770868949.149962     482 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
print(f"Legacy Keras Enabled: {str(os.environ.get('TF_USE_LEGACY_KERAS'))}")
# Out:
# Legacy Keras Enabled: 1

# %%
# CONFIGURATION 
DATASET = 'breastmnist'
BATCH_SIZE = 8 
EPOCHS = 30

# %%
# MIXED PRECISION SETUP 
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
print(f"Policy: {policy.name} | Compute: {policy.compute_dtype}")
# Out:
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   Tesla P100-PCIE-16GB, compute capability 6.0
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once
# Policy: mixed_float16 | Compute: float16

# %% [markdown]
# ## Data Loader Function

# %%
# Function: Data Loader
def load_medmnist_data(dataset_flag, size=224, batch_size=8):
    info = INFO[dataset_flag]
    n_classes = len(info['label'])
    DataClass = getattr(medmnist, info['python_class'])

    print(f"Loading {dataset_flag}...")
    train_data = DataClass(split='train', download=True, size=size)
    val_data = DataClass(split='val', download=True, size=size)
    test_data = DataClass(split='test', download=True, size=size)

    X_train, y_train = train_data.imgs, train_data.labels
    X_val, y_val = val_data.imgs, val_data.labels
    X_test, y_test = test_data.imgs, test_data.labels

    if X_train.shape[-1] != 3:
        X_train = np.repeat(X_train[..., np.newaxis], 3, -1)
        X_val = np.repeat(X_val[..., np.newaxis], 3, -1)
        X_test = np.repeat(X_test[..., np.newaxis], 3, -1)

    X_train = X_train.astype('float32')
    X_val = X_val.astype('float32')
    X_test = X_test.astype('float32')

    y_train_enc = to_categorical(y_train, n_classes)
    y_val_enc = to_categorical(y_val, n_classes)
    y_test_enc = to_categorical(y_test, n_classes)

    train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train_enc))\
        .shuffle(1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val_enc)).batch(batch_size)
    test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test_enc)).batch(batch_size)

    return train_ds, val_ds, test_ds, n_classes, y_test, X_test

# %% [markdown]
# ## Model Loader Function

# %%
# Function: Model Loader 
def get_model(model_name, n_classes, input_shape=(224, 224, 3)):
    inputs = layers.Input(shape=input_shape)
    
    if model_name == 'EfficientNetV2M':
        base = applications.EfficientNetV2M(include_top=False, weights='imagenet', input_tensor=inputs)
        x = layers.GlobalAveragePooling2D()(base.output)
        # Force float32 for stability in final layer
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)
        return models.Model(inputs=inputs, outputs=outputs, name=model_name)

    elif model_name == 'InceptionResNetV2':
        x = layers.Rescaling(1./127.5, offset=-1)(inputs)
        base = applications.InceptionResNetV2(include_top=False, weights='imagenet', input_tensor=x)
        x = layers.GlobalAveragePooling2D()(base.output)
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)
        return models.Model(inputs=inputs, outputs=outputs, name=model_name)

    elif model_name == 'ConvNeXtBase':
        base = applications.ConvNeXtBase(include_top=False, weights='imagenet', input_tensor=inputs)
        x = layers.GlobalAveragePooling2D()(base.output)
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)
        return models.Model(inputs=inputs, outputs=outputs, name=model_name)

    elif model_name == 'ViT-Base':
        x = layers.Rescaling(1./127.5, offset=-1)(inputs)
        x = layers.Permute((3, 1, 2))(x)
        backbone = TFViTForImageClassification.from_pretrained(
            'google/vit-base-patch16-224', num_labels=n_classes, 
            ignore_mismatched_sizes=True, use_safetensors=False)
        outputs = backbone.vit(x)[0]
        outputs = backbone.classifier(outputs[:, 0, :])
        outputs = layers.Activation('softmax', dtype='float32')(outputs)
        return models.Model(inputs=inputs, outputs=outputs, name=model_name)

    else:
        raise ValueError("Unknown Model")

# %% [markdown]
# ## Trainer Function

# %%
# Function: Model Trainer
def train_and_save(model_name):
    print(f"\n{'='*20} TRAINING {model_name} {'='*20}")
    tf.keras.backend.clear_session()
    gc.collect()
    
    if os.path.exists(f"{model_name}_{DATASET}.keras"):
        print(f"Found existing model: {model_name}_{DATASET}.keras. Loading weights...")
        model = get_model(model_name, n_classes)
        model.load_weights(f"{model_name}_{DATASET}.keras")
        
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    else:
        # Train from scratch
        model = get_model(model_name, n_classes)
        lr = 2e-5 if model_name in ['ViT-Base'] else 1e-4
        model.compile(optimizer=tf.keras.optimizers.Adam(lr), 
                      loss='categorical_crossentropy', metrics=['accuracy'])
        
        callbacks = [
            ModelCheckpoint(f"{model_name}_{DATASET}.keras", save_best_only=True, monitor='val_accuracy', mode='max', verbose=1),
            ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1),
            EarlyStopping(monitor='val_accuracy', patience=7, restore_best_weights=True, verbose=1)
        ]
        model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS, callbacks=callbacks, verbose=1)
        # Load best weights
        model.load_weights(f"{model_name}_{DATASET}.keras")

    # Generate Predictions
    print(f"Generating predictions for {model_name}...")
    
    # Validation Set
    val_preds = model.predict(val_ds)
    np.save(f"{model_name}_val_preds.npy", val_preds)
    
    # Test Set
    test_preds = model.predict(test_ds)
    np.save(f"{model_name}_preds.npy", test_preds)
    
    # Test Accuracy
    acc = accuracy_score(y_true_flat, np.argmax(test_preds, axis=1))
    print(f"{model_name} Test Accuracy: {acc:.4f}")
    
    del model
    gc.collect()
    return acc

# %%
# LOAD DATA
train_ds, val_ds, test_ds, n_classes, y_test_true, X_test_raw = load_medmnist_data(DATASET, batch_size=BATCH_SIZE)
y_true_flat = y_test_true.flatten()
y_true_cat = to_categorical(y_true_flat, n_classes)
print(f"Data Ready. Classes: {n_classes}")
# Out:
# Loading breastmnist...
# 100%|██████████| 30.9M/30.9M [00:04<00:00, 6.95MB/s]
# I0000 00:00:1770868974.781523     482 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Data Ready. Classes: 2

# %% [markdown]
# ## Training

# %%
train_and_save('ViT-Base')
# Out:
# ==================== TRAINING ViT-Base ====================
# config.json: 0.00B [00:00, ?B/s]
# tf_model.h5:   0%|          | 0.00/347M [00:00<?, ?B/s]
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# All model checkpoint layers were used when initializing TFViTForImageClassification.
#
# Some weights of TFViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier/kernel:0: found shape (768, 1000) in the checkpoint and (768, 2) in the model instantiated
# - classifier/bias:0: found shape (1000,) in the checkpoint and (2,) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30
# I0000 00:00:1770869014.243200     543 cuda_dnn.cc:529] Loaded cuDNN version 91002
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1770869016.108925     545 service.cc:152] XLA service 0x7e09c88fd920 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1770869016.108963     545 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1770869016.501337     543 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 69/69 [==============================] - ETA: 0s - loss: 0.4220 - accuracy: 0.8315
# Epoch 1: val_accuracy improved from -inf to 0.91026, saving model to ViT-Base_breastmnist.keras
# 69/69 [==============================] - 76s 369ms/step - loss: 0.4220 - accuracy: 0.8315 - val_loss: 0.2599 - val_accuracy: 0.9103 - lr: 2.0000e-05
# Epoch 2/30
# 69/69 [==============================] - ETA: 0s - loss: 0.1512 - accuracy: 0.9487
# Epoch 2: val_accuracy did not improve from 0.91026
# 69/69 [==============================] - 16s 238ms/step - loss: 0.1512 - accuracy: 0.9487 - val_loss: 0.2059 - val_accuracy: 0.8974 - lr: 2.0000e-05
# Epoch 3/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9890
# Epoch 3: val_accuracy did not improve from 0.91026
# 69/69 [==============================] - 17s 240ms/step - loss: 0.0461 - accuracy: 0.9890 - val_loss: 0.3405 - val_accuracy: 0.8846 - lr: 2.0000e-05
# Epoch 4/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9982
# Epoch 4: val_accuracy improved from 0.91026 to 0.93590, saving model to ViT-Base_breastmnist.keras
# 69/69 [==============================] - 23s 340ms/step - loss: 0.0156 - accuracy: 0.9982 - val_loss: 0.2164 - val_accuracy: 0.9359 - lr: 2.0000e-05
# Epoch 5/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9982
# Epoch 5: val_accuracy did not improve from 0.93590
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 69/69 [==============================] - 16s 239ms/step - loss: 0.0077 - accuracy: 0.9982 - val_loss: 0.2712 - val_accuracy: 0.9103 - lr: 2.0000e-05
# Epoch 6/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9982
# Epoch 6: val_accuracy did not improve from 0.93590
# 69/69 [==============================] - 16s 238ms/step - loss: 0.0050 - accuracy: 0.9982 - val_loss: 0.2809 - val_accuracy: 0.9103 - lr: 1.0000e-05
# Epoch 7/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 0.93590
# 69/69 [==============================] - 16s 238ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2997 - val_accuracy: 0.9103 - lr: 1.0000e-05
# Epoch 8/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.93590
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 69/69 [==============================] - 16s 238ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2871 - val_accuracy: 0.9103 - lr: 1.0000e-05
# Epoch 9/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.93590
# 69/69 [==============================] - 16s 239ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3096 - val_accuracy: 0.9103 - lr: 5.0000e-06
# Epoch 10/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.93590
# 69/69 [==============================] - 16s 238ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3167 - val_accuracy: 0.9103 - lr: 5.0000e-06
# Epoch 11/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.93590
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 69/69 [==============================] - 16s 238ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3223 - val_accuracy: 0.9103 - lr: 5.0000e-06
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Generating predictions for ViT-Base...
# 10/10 [==============================] - 3s 77ms/step
# 20/20 [==============================] - 2s 76ms/step
# ViT-Base Test Accuracy: 0.9038
# 0.9038461538461539

# %%
train_and_save('ConvNeXtBase')
# Out:
# ==================== TRAINING ConvNeXtBase ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 [==============================] - 16s 0us/step
# Epoch 1/30
# 2026-02-12 04:09:01.881026: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 04:09:02.067001: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 04:09:02.255434: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 04:09:02.532669: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 04:09:02.745347: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 04:09:02.962145: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 04:09:03.178540: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 04:09:03.278668: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng4{} for conv %cudnn-conv.3 = (f16[1,1024,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,8192,7,7]{3,2,1,0} %bitcast.159, f16[1024,8,7,7]{3,2,1,0} %bitcast.166), window={size=7x7 pad=3_3x3_3}, dim_labels=bf01_oi01->bf01, feature_group_count=1024, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2DBackpropFilter" op_name="gradients/Conv2D_grad/Conv2DBackpropFilter" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-02-12 04:09:03.388367: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 04:09:03.609322: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 04:09:03.820548: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 04:09:03.838675: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.560152491s
# Trying algorithm eng4{} for conv %cudnn-conv.3 = (f16[1,1024,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f16[1,8192,7,7]{3,2,1,0} %bitcast.159, f16[1024,8,7,7]{3,2,1,0} %bitcast.166), window={size=7x7 pad=3_3x3_3}, dim_labels=bf01_oi01->bf01, feature_group_count=1024, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2DBackpropFilter" op_name="gradients/Conv2D_grad/Conv2DBackpropFilter" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 68/69 [============================>.] - ETA: 0s - loss: 0.5465 - accuracy: 0.7537
# 2026-02-12 04:11:11.053916: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 04:11:11.271956: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-12 04:11:11.483051: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 69/69 [==============================] - ETA: 0s - loss: 0.5447 - accuracy: 0.7546
# Epoch 1: val_accuracy improved from -inf to 0.89744, saving model to ConvNeXtBase_breastmnist.keras
# 69/69 [==============================] - 328s 3s/step - loss: 0.5447 - accuracy: 0.7546 - val_loss: 0.2406 - val_accuracy: 0.8974 - lr: 1.0000e-04
# Epoch 2/30
# 69/69 [==============================] - ETA: 0s - loss: 0.2644 - accuracy: 0.8864
# Epoch 2: val_accuracy did not improve from 0.89744
# 69/69 [==============================] - 20s 295ms/step - loss: 0.2644 - accuracy: 0.8864 - val_loss: 0.3155 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 3/30
# 69/69 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 0.9542
# Epoch 3: val_accuracy improved from 0.89744 to 0.93590, saving model to ConvNeXtBase_breastmnist.keras
# 69/69 [==============================] - 28s 404ms/step - loss: 0.1266 - accuracy: 0.9542 - val_loss: 0.2018 - val_accuracy: 0.9359 - lr: 1.0000e-04
# Epoch 4/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9799
# Epoch 4: val_accuracy did not improve from 0.93590
# 69/69 [==============================] - 20s 294ms/step - loss: 0.0559 - accuracy: 0.9799 - val_loss: 0.2378 - val_accuracy: 0.9359 - lr: 1.0000e-04
# Epoch 5/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9908
# Epoch 5: val_accuracy did not improve from 0.93590
# 69/69 [==============================] - 20s 293ms/step - loss: 0.0193 - accuracy: 0.9908 - val_loss: 0.4041 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 6/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9945
# Epoch 6: val_accuracy improved from 0.93590 to 0.94872, saving model to ConvNeXtBase_breastmnist.keras
# 69/69 [==============================] - 28s 412ms/step - loss: 0.0256 - accuracy: 0.9945 - val_loss: 0.1668 - val_accuracy: 0.9487 - lr: 1.0000e-04
# Epoch 7/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9963
# Epoch 7: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 20s 295ms/step - loss: 0.0159 - accuracy: 0.9963 - val_loss: 0.4506 - val_accuracy: 0.8974 - lr: 1.0000e-04
# Epoch 8/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9982
# Epoch 8: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 20s 294ms/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.2193 - val_accuracy: 0.9487 - lr: 1.0000e-04
# Epoch 9/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9982
# Epoch 9: val_accuracy improved from 0.94872 to 0.96154, saving model to ConvNeXtBase_breastmnist.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 69/69 [==============================] - 27s 397ms/step - loss: 0.0040 - accuracy: 0.9982 - val_loss: 0.1718 - val_accuracy: 0.9615 - lr: 1.0000e-04
# Epoch 10/30
# 69/69 [==============================] - ETA: 0s - loss: 4.3473e-04 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.96154
# 69/69 [==============================] - 20s 294ms/step - loss: 4.3473e-04 - accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9615 - lr: 5.0000e-05
# Epoch 11/30
# 69/69 [==============================] - ETA: 0s - loss: 2.6575e-04 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.96154
# 69/69 [==============================] - 20s 294ms/step - loss: 2.6575e-04 - accuracy: 1.0000 - val_loss: 0.1792 - val_accuracy: 0.9615 - lr: 5.0000e-05
# Epoch 12/30
# 69/69 [==============================] - ETA: 0s - loss: 2.1315e-04 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.96154
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 69/69 [==============================] - 20s 294ms/step - loss: 2.1315e-04 - accuracy: 1.0000 - val_loss: 0.1833 - val_accuracy: 0.9615 - lr: 5.0000e-05
# Epoch 13/30
# 69/69 [==============================] - ETA: 0s - loss: 1.8464e-04 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.96154
# 69/69 [==============================] - 20s 294ms/step - loss: 1.8464e-04 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9615 - lr: 2.5000e-05
# Epoch 14/30
# 69/69 [==============================] - ETA: 0s - loss: 1.7046e-04 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.96154
# 69/69 [==============================] - 20s 294ms/step - loss: 1.7046e-04 - accuracy: 1.0000 - val_loss: 0.1863 - val_accuracy: 0.9615 - lr: 2.5000e-05
# Epoch 15/30
# 69/69 [==============================] - ETA: 0s - loss: 1.5778e-04 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.96154
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 69/69 [==============================] - 20s 294ms/step - loss: 1.5778e-04 - accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9615 - lr: 2.5000e-05
# Epoch 16/30
# 69/69 [==============================] - ETA: 0s - loss: 1.4790e-04 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.96154
# 69/69 [==============================] - 20s 293ms/step - loss: 1.4790e-04 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9615 - lr: 1.2500e-05
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Generating predictions for ConvNeXtBase...
# 10/10 [==============================] - 4s 96ms/step
# 20/20 [==============================] - 33s 2s/step
# ConvNeXtBase Test Accuracy: 0.9103
# 0.9102564102564102

# %%
train_and_save('EfficientNetV2M')
# Out:
# ==================== TRAINING EfficientNetV2M ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 11s 0us/step
# Epoch 1/30
# E0000 00:00:1770870054.369332     482 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inEfficientNetV2M/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 69/69 [==============================] - ETA: 0s - loss: 0.5289 - accuracy: 0.7399
# Epoch 1: val_accuracy improved from -inf to 0.83333, saving model to EfficientNetV2M_breastmnist.keras
# 69/69 [==============================] - 210s 871ms/step - loss: 0.5289 - accuracy: 0.7399 - val_loss: 0.3161 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 2/30
# 69/69 [==============================] - ETA: 0s - loss: 0.2204 - accuracy: 0.9158
# Epoch 2: val_accuracy improved from 0.83333 to 0.87179, saving model to EfficientNetV2M_breastmnist.keras
# 69/69 [==============================] - 20s 294ms/step - loss: 0.2204 - accuracy: 0.9158 - val_loss: 0.2948 - val_accuracy: 0.8718 - lr: 1.0000e-04
# Epoch 3/30
# 69/69 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9524
# Epoch 3: val_accuracy improved from 0.87179 to 0.91026, saving model to EfficientNetV2M_breastmnist.keras
# 69/69 [==============================] - 20s 292ms/step - loss: 0.1416 - accuracy: 0.9524 - val_loss: 0.2289 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 4/30
# 69/69 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9652
# Epoch 4: val_accuracy did not improve from 0.91026
# 69/69 [==============================] - 13s 193ms/step - loss: 0.1045 - accuracy: 0.9652 - val_loss: 0.2525 - val_accuracy: 0.8974 - lr: 1.0000e-04
# Epoch 5/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9670
# Epoch 5: val_accuracy did not improve from 0.91026
# 69/69 [==============================] - 13s 192ms/step - loss: 0.0851 - accuracy: 0.9670 - val_loss: 0.2396 - val_accuracy: 0.8974 - lr: 1.0000e-04
# Epoch 6/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9780
# Epoch 6: val_accuracy improved from 0.91026 to 0.93590, saving model to EfficientNetV2M_breastmnist.keras
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 69/69 [==============================] - 20s 289ms/step - loss: 0.0770 - accuracy: 0.9780 - val_loss: 0.2542 - val_accuracy: 0.9359 - lr: 1.0000e-04
# Epoch 7/30
# 69/69 [==============================] - ETA: 0s - loss: 0.1015 - accuracy: 0.9670
# Epoch 7: val_accuracy did not improve from 0.93590
# 69/69 [==============================] - 13s 193ms/step - loss: 0.1015 - accuracy: 0.9670 - val_loss: 0.1685 - val_accuracy: 0.9231 - lr: 5.0000e-05
# Epoch 8/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9908
# Epoch 8: val_accuracy improved from 0.93590 to 0.94872, saving model to EfficientNetV2M_breastmnist.keras
# 69/69 [==============================] - 20s 292ms/step - loss: 0.0366 - accuracy: 0.9908 - val_loss: 0.1692 - val_accuracy: 0.9487 - lr: 5.0000e-05
# Epoch 9/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9853
# Epoch 9: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 13s 193ms/step - loss: 0.0398 - accuracy: 0.9853 - val_loss: 0.1650 - val_accuracy: 0.9359 - lr: 5.0000e-05
# Epoch 10/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9945
# Epoch 10: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 13s 192ms/step - loss: 0.0223 - accuracy: 0.9945 - val_loss: 0.1611 - val_accuracy: 0.9231 - lr: 5.0000e-05
# Epoch 11/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9927
# Epoch 11: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 13s 192ms/step - loss: 0.0363 - accuracy: 0.9927 - val_loss: 0.1952 - val_accuracy: 0.9231 - lr: 5.0000e-05
# Epoch 12/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9963
# Epoch 12: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 13s 192ms/step - loss: 0.0328 - accuracy: 0.9963 - val_loss: 0.1632 - val_accuracy: 0.9103 - lr: 5.0000e-05
# Epoch 13/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 13s 191ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9359 - lr: 5.0000e-05
# Epoch 14/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9963
# Epoch 14: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 13s 192ms/step - loss: 0.0150 - accuracy: 0.9963 - val_loss: 0.1378 - val_accuracy: 0.9231 - lr: 5.0000e-05
# Epoch 15/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9927
# Epoch 15: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 13s 192ms/step - loss: 0.0250 - accuracy: 0.9927 - val_loss: 0.2819 - val_accuracy: 0.9103 - lr: 5.0000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Generating predictions for EfficientNetV2M...
# 10/10 [==============================] - 5s 46ms/step
# 20/20 [==============================] - 6s 319ms/step
# EfficientNetV2M Test Accuracy: 0.9103
# 0.9102564102564102

# %%
train_and_save('InceptionResNetV2')
# Out:
# ==================== TRAINING InceptionResNetV2 ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 11s 0us/step
# Epoch 1/30
# 69/69 [==============================] - ETA: 0s - loss: 0.5502 - accuracy: 0.7436
# Epoch 1: val_accuracy improved from -inf to 0.76923, saving model to InceptionResNetV2_breastmnist.keras
# 69/69 [==============================] - 183s 854ms/step - loss: 0.5502 - accuracy: 0.7436 - val_loss: 0.4380 - val_accuracy: 0.7692 - lr: 1.0000e-04
# Epoch 2/30
# 69/69 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.8919
# Epoch 2: val_accuracy improved from 0.76923 to 0.87179, saving model to InceptionResNetV2_breastmnist.keras
# 69/69 [==============================] - 19s 283ms/step - loss: 0.2885 - accuracy: 0.8919 - val_loss: 0.2831 - val_accuracy: 0.8718 - lr: 1.0000e-04
# Epoch 3/30
# 69/69 [==============================] - ETA: 0s - loss: 0.1444 - accuracy: 0.9469
# Epoch 3: val_accuracy did not improve from 0.87179
# 69/69 [==============================] - 13s 183ms/step - loss: 0.1444 - accuracy: 0.9469 - val_loss: 0.4176 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 4/30
# 69/69 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9597
# Epoch 4: val_accuracy improved from 0.87179 to 0.91026, saving model to InceptionResNetV2_breastmnist.keras
# 69/69 [==============================] - 19s 279ms/step - loss: 0.1253 - accuracy: 0.9597 - val_loss: 0.1952 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 5/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0843 - accuracy: 0.9725
# Epoch 5: val_accuracy did not improve from 0.91026
# 69/69 [==============================] - 12s 181ms/step - loss: 0.0843 - accuracy: 0.9725 - val_loss: 0.3190 - val_accuracy: 0.8846 - lr: 1.0000e-04
# Epoch 6/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9744
# Epoch 6: val_accuracy did not improve from 0.91026
# 69/69 [==============================] - 12s 181ms/step - loss: 0.0785 - accuracy: 0.9744 - val_loss: 0.7138 - val_accuracy: 0.8846 - lr: 1.0000e-04
# Epoch 7/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9927
# Epoch 7: val_accuracy did not improve from 0.91026
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 69/69 [==============================] - 13s 182ms/step - loss: 0.0330 - accuracy: 0.9927 - val_loss: 0.3924 - val_accuracy: 0.8974 - lr: 1.0000e-04
# Epoch 8/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9927
# Epoch 8: val_accuracy did not improve from 0.91026
# 69/69 [==============================] - 12s 181ms/step - loss: 0.0228 - accuracy: 0.9927 - val_loss: 0.2374 - val_accuracy: 0.9103 - lr: 5.0000e-05
# Epoch 9/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9927
# Epoch 9: val_accuracy did not improve from 0.91026
# 69/69 [==============================] - 12s 181ms/step - loss: 0.0282 - accuracy: 0.9927 - val_loss: 0.3329 - val_accuracy: 0.9103 - lr: 5.0000e-05
# Epoch 10/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9890
# Epoch 10: val_accuracy improved from 0.91026 to 0.93590, saving model to InceptionResNetV2_breastmnist.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 69/69 [==============================] - 19s 280ms/step - loss: 0.0362 - accuracy: 0.9890 - val_loss: 0.2421 - val_accuracy: 0.9359 - lr: 5.0000e-05
# Epoch 11/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9945
# Epoch 11: val_accuracy improved from 0.93590 to 0.94872, saving model to InceptionResNetV2_breastmnist.keras
# 69/69 [==============================] - 19s 282ms/step - loss: 0.0288 - accuracy: 0.9945 - val_loss: 0.2207 - val_accuracy: 0.9487 - lr: 2.5000e-05
# Epoch 12/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9982
# Epoch 12: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 13s 184ms/step - loss: 0.0109 - accuracy: 0.9982 - val_loss: 0.2552 - val_accuracy: 0.9487 - lr: 2.5000e-05
# Epoch 13/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9982
# Epoch 13: val_accuracy did not improve from 0.94872
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 69/69 [==============================] - 13s 181ms/step - loss: 0.0139 - accuracy: 0.9982 - val_loss: 0.2082 - val_accuracy: 0.9487 - lr: 2.5000e-05
# Epoch 14/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 13s 184ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9487 - lr: 1.2500e-05
# Epoch 15/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 13s 182ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2517 - val_accuracy: 0.9487 - lr: 1.2500e-05
# Epoch 16/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9982
# Epoch 16: val_accuracy did not improve from 0.94872
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 69/69 [==============================] - 13s 184ms/step - loss: 0.0094 - accuracy: 0.9982 - val_loss: 0.1999 - val_accuracy: 0.9487 - lr: 1.2500e-05
# Epoch 17/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 13s 182ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9487 - lr: 6.2500e-06
# Epoch 18/30
# 69/69 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9982
# Epoch 18: val_accuracy did not improve from 0.94872
# 69/69 [==============================] - 13s 182ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.2316 - val_accuracy: 0.9487 - lr: 6.2500e-06
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Generating predictions for InceptionResNetV2...
# 10/10 [==============================] - 4s 47ms/step
# 20/20 [==============================] - 2s 86ms/step
# InceptionResNetV2 Test Accuracy: 0.9038
# 0.9038461538461539

# %% [markdown]
# ## Ensemble (Soft Voting) & Results

# %%
# ENSEMBLE ANALYSIS 
print(f"\n{'='*30}\nENSEMBLE EXECUTION\n{'='*30}")

MODELS_TO_LOAD = ['ConvNeXtBase', 'ViT-Base', 'EfficientNetV2M', 'InceptionResNetV2']
loaded_preds = []
valid_models = []

for m in MODELS_TO_LOAD:
    filename = f"{m}_preds.npy"
    if os.path.exists(filename):
        print(f"Loading {filename}...")
        loaded_preds.append(np.load(filename))
        valid_models.append(m)
    else:
        print(f"Warning: {filename} not found. Skipping.")

if not loaded_preds:
    raise ValueError("No predictions found! Train at least one model first.")

# Stack and Average
all_preds = np.array(loaded_preds) # Shape: (Num_Models, N_Samples, N_Classes)
ensemble_probs = np.mean(all_preds, axis=0)

y_pred_ensemble = np.argmax(ensemble_probs, axis=1)

# Metrics
print("\n>>> Classification Report:")
print(classification_report(y_true_flat, y_pred_ensemble))

ens_acc = accuracy_score(y_true_flat, y_pred_ensemble)
ens_auc = roc_auc_score(y_true_cat, ensemble_probs, multi_class='ovr')
ens_loss = log_loss(y_true_cat, ensemble_probs)

print(f"Ensemble Accuracy: {ens_acc:.4f}")
print(f"Ensemble AUC:      {ens_auc:.4f}")

fig, axes = plt.subplots(1, 3, figsize=(20, 5))

# Confusion Matrix
cm = confusion_matrix(y_true_flat, y_pred_ensemble)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title(f'Ensemble Confusion Matrix (Acc: {ens_acc:.2%})')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('True')

# Uncertainty (Entropy)
entropy = -np.sum(ensemble_probs * np.log(ensemble_probs + 1e-9), axis=1)
correct_mask = (y_pred_ensemble == y_true_flat)

sns.kdeplot(entropy[correct_mask], label='Correct', fill=True, color='green', ax=axes[1])
sns.kdeplot(entropy[~correct_mask], label='Wrong', fill=True, color='red', ax=axes[1])
axes[1].set_title('Uncertainty (Entropy) Distribution')
axes[1].legend()

# Calibration (Top-Class)
is_correct = (y_pred_ensemble == y_true_flat).astype(int)
pred_confidence = np.max(ensemble_probs, axis=1)
prob_true, prob_pred = calibration_curve(is_correct, pred_confidence, n_bins=10, strategy='quantile')

axes[2].plot(prob_pred, prob_true, marker='o', label='Ensemble', color='purple')
axes[2].plot([0, 1], [0, 1], linestyle='--', color='gray', label='Perfect')
axes[2].set_title('Reliability Diagram')
axes[2].set_xlabel('Confidence')
axes[2].set_ylabel('Accuracy')
axes[2].legend()
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ==============================
# ENSEMBLE EXECUTION
# ==============================
# Loading ConvNeXtBase_preds.npy...
# Loading ViT-Base_preds.npy...
# Loading EfficientNetV2M_preds.npy...
# Loading InceptionResNetV2_preds.npy...
#
# >>> Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85        42
#            1       0.93      0.96      0.95       114
#
#     accuracy                           0.92       156
#    macro avg       0.91      0.89      0.90       156
# weighted avg       0.92      0.92      0.92       156
#
# Ensemble Accuracy: 0.9231
# Ensemble AUC:      0.9363

# %% [markdown]
# ## Individual Model Results

# %%
MODELS_TO_LOAD = ['ConvNeXtBase', 'ViT-Base', 'EfficientNetV2M', 'InceptionResNetV2']

print(f"\n{'='*50}\nINDIVIDUAL MODEL DIAGNOSTICS\n{'='*50}")

model_scores = {}

for model_name in MODELS_TO_LOAD:
    filename = f"{model_name}_preds.npy"
    
    if not os.path.exists(filename):
        print(f"Warning: {filename} not found. Skipping.")
        continue

    # Load Predictions
    preds_probs = np.load(filename)
    y_pred = np.argmax(preds_probs, axis=1)

    # Calculate Metrics
    acc = accuracy_score(y_true_flat, y_pred)
    auc = roc_auc_score(y_true_cat, preds_probs, multi_class='ovr')
    model_scores[model_name] = acc

    print(f"\n{'='*20} {model_name} {'='*20}")
    print(f"Accuracy: {acc:.4%}")
    print(f"AUC:      {auc:.4f}")
    print("-" * 60)
    print(classification_report(y_true_flat, y_pred))

    # Plotting Suite
    fig, axes = plt.subplots(1, 3, figsize=(20, 5))

    # Confusion Matrix
    cm = confusion_matrix(y_true_flat, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', ax=axes[0])
    axes[0].set_title(f'{model_name} Confusion Matrix')
    axes[0].set_xlabel('Predicted Label')
    axes[0].set_ylabel('True Label')

    # Uncertainty (Entropy) Distribution
    entropy = -np.sum(preds_probs * np.log(preds_probs + 1e-9), axis=1)
    correct_mask = (y_pred == y_true_flat)
    
    sns.kdeplot(entropy[correct_mask], label='Correct', fill=True, color='green', ax=axes[1])
    sns.kdeplot(entropy[~correct_mask], label='Wrong', fill=True, color='red', ax=axes[1])
    axes[1].set_title(f'{model_name} Uncertainty Profile')
    axes[1].set_xlabel('Entropy (Uncertainty)')
    axes[1].legend()

    # Reliability Diagram (Calibration)
    is_correct = (y_pred == y_true_flat).astype(int)
    pred_conf = np.max(preds_probs, axis=1)
    prob_true, prob_pred = calibration_curve(is_correct, pred_conf, n_bins=10, strategy='quantile')
    
    axes[2].plot(prob_pred, prob_true, marker='o', label=model_name, color='darkorange')
    axes[2].plot([0, 1], [0, 1], linestyle='--', color='gray', label='Perfect')
    axes[2].set_title(f'{model_name} Reliability')
    axes[2].set_xlabel('Confidence')
    axes[2].set_ylabel('Accuracy')
    axes[2].legend()
    axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# Summary Comparison Table
print("\n" + "="*30)
print("FINAL PERFORMANCE SUMMARY")
print("="*30)
print(f"{'Model Name':<20} | {'Accuracy':<10}")
print("-" * 35)
for name, score in model_scores.items():
    print(f"{name:<20} | {score:.4%}")
print("-" * 35)
# Out:
# ==================================================
# INDIVIDUAL MODEL DIAGNOSTICS
# ==================================================
#
# ==================== ConvNeXtBase ====================
# Accuracy: 91.0256%
# AUC:      0.9196
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      0.74      0.82        42
#            1       0.91      0.97      0.94       114
#
#     accuracy                           0.91       156
#    macro avg       0.91      0.86      0.88       156
# weighted avg       0.91      0.91      0.91       156
# ==================== ViT-Base ====================
# Accuracy: 90.3846%
# AUC:      0.9327
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.81        42
#            1       0.92      0.95      0.94       114
#
#     accuracy                           0.90       156
#    macro avg       0.88      0.87      0.87       156
# weighted avg       0.90      0.90      0.90       156
# ==================== EfficientNetV2M ====================
# Accuracy: 91.0256%
# AUC:      0.9246
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.82        42
#            1       0.92      0.96      0.94       114
#
#     accuracy                           0.91       156
#    macro avg       0.90      0.87      0.88       156
# weighted avg       0.91      0.91      0.91       156
# ==================== InceptionResNetV2 ====================
# Accuracy: 90.3846%
# AUC:      0.8843
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82        42
#            1       0.93      0.94      0.93       114
#
#     accuracy                           0.90       156
#    macro avg       0.88      0.87      0.88       156
# weighted avg       0.90      0.90      0.90       156
# ==============================
# FINAL PERFORMANCE SUMMARY
# ==============================
# Model Name           | Accuracy
# -----------------------------------
# ConvNeXtBase         | 91.0256%
# ViT-Base             | 90.3846%
# EfficientNetV2M      | 91.0256%
# InceptionResNetV2    | 90.3846%
# -----------------------------------

# %% [markdown]
# ## Stacking & Results

# %%
from tensorflow.keras import  callbacks 

print(f"\n{'='*30}\nRIGOROUS STACKING (No Data Leakage)\n{'='*30}")
MODELS_TO_LOAD = ['ConvNeXtBase', 'ViT-Base', 'EfficientNetV2M', 'InceptionResNetV2']

# training meta-data  (From Validation Set)
print("Loading VALIDATION predictions (Meta-Train)...")
val_preds_list = []
for m in MODELS_TO_LOAD:
    filename = f"{m}_val_preds.npy"
    if os.path.exists(filename):
        val_preds_list.append(np.load(filename))
    else:
        raise ValueError(f"Missing validation preds for {m}. Re-run training cell.")

X_meta_train = np.concatenate(val_preds_list, axis=1) # (N_Val, 32)

# labels for the validation set
y_val_true = np.concatenate([y for x, y in val_ds], axis=0)
y_val_flat = np.argmax(y_val_true, axis=1)

print(f"Meta-Train Input Shape: {X_meta_train.shape}")


# testing meta-data (From Test Set) 
print("Loading TEST predictions (Meta-Eval)...")
test_preds_list = []
for m in MODELS_TO_LOAD:
    filename = f"{m}_preds.npy"
    if os.path.exists(filename):
        test_preds_list.append(np.load(filename))
    else:
        raise ValueError(f"Missing test preds for {m}.")

X_meta_test = np.concatenate(test_preds_list, axis=1) # (N_Test, 32)

print(f"Meta-Test Input Shape:  {X_meta_test.shape}")


# train
def get_meta_learner(input_dim, n_classes):
    inputs = layers.Input(shape=(input_dim,))
    
    # Small MLP
    x = layers.Dense(64, activation='relu')(inputs)
    x = layers.Dropout(0.5)(x) 
    x = layers.Dense(32, activation='relu')(x)
    
    outputs = layers.Dense(n_classes, activation='softmax')(x)
    return models.Model(inputs=inputs, outputs=outputs, name="Meta_Learner")

meta_model = get_meta_learner(X_meta_train.shape[1], n_classes)
meta_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

print("\nTraining Meta-Learner on Validation Set...")

history = meta_model.fit(
    X_meta_train, y_val_true,
    epochs=50,
    batch_size=16,
    validation_split=0.1, # Use 10% of Val set to check for overfitting
    callbacks=[callbacks.EarlyStopping(patience=5, restore_best_weights=True)],
    verbose=1
)

# Final evaluation on test set
meta_probs = meta_model.predict(X_meta_test)
y_pred_meta = np.argmax(meta_probs, axis=1)

# Metrics
acc_meta = accuracy_score(y_true_flat, y_pred_meta)
auc_meta = roc_auc_score(y_true_cat, meta_probs, multi_class='ovr')

print(f"\n>>> Final Stacking Results (Full Test Set):")
print(f"Stacking Accuracy: {acc_meta:.4f}")
print(f"Stacking AUC:      {auc_meta:.4f}")
print("-" * 30)

# Calculate Reference Soft Voting (for comparison)
X_test_reshaped = X_meta_test.reshape(-1, len(MODELS_TO_LOAD), n_classes) 
soft_vote_probs = np.mean(X_test_reshaped, axis=1)
acc_soft = accuracy_score(y_true_flat, np.argmax(soft_vote_probs, axis=1))

print(f"Reference Soft Voting: {acc_soft:.4f}")

fig, axes = plt.subplots(1, 3, figsize=(20, 5))

# Confusion Matrix
cm = confusion_matrix(y_true_flat, y_pred_meta)
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', ax=axes[0])
axes[0].set_title(f'Stacking Confusion Matrix (Acc: {acc_meta:.2%})')
axes[0].set_ylabel('True'); axes[0].set_xlabel('Predicted')

# Uncertainty
entropy = -np.sum(meta_probs * np.log(meta_probs + 1e-9), axis=1)
correct_mask = (y_pred_meta == y_true_flat)
sns.kdeplot(entropy[correct_mask], label='Correct', fill=True, color='green', ax=axes[1])
sns.kdeplot(entropy[~correct_mask], label='Wrong', fill=True, color='red', ax=axes[1])
axes[1].set_title('Stacking Uncertainty')
axes[1].legend()

# Calibration
is_correct = (y_pred_meta == y_true_flat).astype(int)
pred_conf = np.max(meta_probs, axis=1)
prob_true, prob_pred = calibration_curve(is_correct, pred_conf, n_bins=10, strategy='quantile')
axes[2].plot(prob_pred, prob_true, marker='o', label='Meta-Learner', color='darkgreen')
axes[2].plot([0, 1], [0, 1], linestyle='--', color='gray')
axes[2].set_title('Reliability Diagram')
axes[2].legend()

plt.tight_layout()
plt.show()
# Out:
# ==============================
# RIGOROUS STACKING (No Data Leakage)
# ==============================
# Loading VALIDATION predictions (Meta-Train)...
# Meta-Train Input Shape: (78, 8)
# Loading TEST predictions (Meta-Eval)...
# Meta-Test Input Shape:  (156, 8)
#
# Training Meta-Learner on Validation Set...
# Epoch 1/50
# 5/5 [==============================] - 1s 44ms/step - loss: 0.5004 - accuracy: 0.7286 - val_loss: 0.3931 - val_accuracy: 1.0000
# Epoch 2/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3976 - accuracy: 0.8429 - val_loss: 0.3391 - val_accuracy: 1.0000
# Epoch 3/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3531 - accuracy: 0.9143 - val_loss: 0.2915 - val_accuracy: 1.0000
# Epoch 4/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3031 - accuracy: 0.8857 - val_loss: 0.2473 - val_accuracy: 1.0000
# Epoch 5/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2854 - accuracy: 0.8857 - val_loss: 0.2095 - val_accuracy: 1.0000
# Epoch 6/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2799 - accuracy: 0.8857 - val_loss: 0.1792 - val_accuracy: 1.0000
# Epoch 7/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2225 - accuracy: 0.9143 - val_loss: 0.1526 - val_accuracy: 1.0000
# Epoch 8/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2307 - accuracy: 0.9286 - val_loss: 0.1289 - val_accuracy: 1.0000
# Epoch 9/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2320 - accuracy: 0.9143 - val_loss: 0.1103 - val_accuracy: 1.0000
# Epoch 10/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2186 - accuracy: 0.9429 - val_loss: 0.0958 - val_accuracy: 1.0000
# Epoch 11/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1830 - accuracy: 0.9286 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 12/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1568 - accuracy: 0.9429 - val_loss: 0.0717 - val_accuracy: 1.0000
# Epoch 13/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1792 - accuracy: 0.9143 - val_loss: 0.0623 - val_accuracy: 1.0000
# Epoch 14/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1717 - accuracy: 0.9286 - val_loss: 0.0542 - val_accuracy: 1.0000
# Epoch 15/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1427 - accuracy: 0.9286 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 16/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1596 - accuracy: 0.9429 - val_loss: 0.0435 - val_accuracy: 1.0000
# Epoch 17/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1339 - accuracy: 0.9429 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 18/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1339 - accuracy: 0.9429 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 19/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1461 - accuracy: 0.9429 - val_loss: 0.0317 - val_accuracy: 1.0000
# Epoch 20/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1329 - accuracy: 0.9286 - val_loss: 0.0289 - val_accuracy: 1.0000
# Epoch 21/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1073 - accuracy: 0.9286 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 22/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1451 - accuracy: 0.9571 - val_loss: 0.0243 - val_accuracy: 1.0000
# Epoch 23/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1672 - accuracy: 0.9429 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 24/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1399 - accuracy: 0.9429 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 25/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1317 - accuracy: 0.9571 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 26/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1190 - accuracy: 0.9429 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 27/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1264 - accuracy: 0.9429 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 28/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1386 - accuracy: 0.9286 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 29/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1402 - accuracy: 0.9571 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 30/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1510 - accuracy: 0.9286 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 31/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1431 - accuracy: 0.9571 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 32/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1113 - accuracy: 0.9714 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 33/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1124 - accuracy: 0.9286 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 34/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1174 - accuracy: 0.9286 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 35/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1268 - accuracy: 0.9714 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 36/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1279 - accuracy: 0.9286 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1400 - accuracy: 0.9429 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1253 - accuracy: 0.9286 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1087 - accuracy: 0.9571 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1256 - accuracy: 0.9571 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1141 - accuracy: 0.9571 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1269 - accuracy: 0.9286 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1528 - accuracy: 0.9429 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1070 - accuracy: 0.9429 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1054 - accuracy: 0.9286 - val_loss: 0.0171 - val_accuracy: 1.0000
# 5/5 [==============================] - 0s 2ms/step
#
# >>> Final Stacking Results (Full Test Set):
# Stacking Accuracy: 0.9359
# Stacking AUC:      0.9374
# ------------------------------
# Reference Soft Voting: 0.9231
