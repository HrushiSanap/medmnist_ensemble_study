# %% [markdown]
# # OrganAMNIST Model Training

# %% [markdown]
# ## Setup and Reproducibility

# %% [markdown]
# !pip install -q "numpy==1.26.4" "scipy==1.13.1"
#
# !pip install -q "transformers==4.44.2" --no-deps
#
# !pip install -q "tokenizers>=0.19,<0.20" "huggingface-hub>=0.23,<0.25" "safetensors>=0.4"
#
# !pip install -q "medmnist" "tf-keras"

# %%
# SETUP AND REPRODUCIBILITY

import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"
os.environ['PYTHONHASHSEED'] = '42'

import random
import numpy as np
import tensorflow as tf

# Global reproducibility seed
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.keras.utils.set_random_seed(SEED)
tf.config.experimental.enable_op_determinism()

# Imports
import medmnist
from medmnist import INFO
import gc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import layers, models, applications, mixed_precision, callbacks
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from transformers import TFViTForImageClassification
from sklearn.metrics import (classification_report, confusion_matrix, accuracy_score,
                              roc_auc_score, precision_score, recall_score, f1_score,
                              average_precision_score, log_loss)
from sklearn.calibration import calibration_curve
from scipy.signal import find_peaks
from scipy.stats import gaussian_kde
import warnings
warnings.filterwarnings('ignore')

print(f"NumPy: {np.__version__}")
print(f"TensorFlow: {tf.__version__}")
print(f"Random Seed: {SEED}")
print(f"Legacy Keras: {os.environ.get('TF_USE_LEGACY_KERAS')}")
# Out:
# NumPy: 1.26.4
# TensorFlow: 2.19.0
# Random Seed: 42
# Legacy Keras: 1

# %% [markdown]
# ## Configuration

# %%
# CONFIGURATION

DATASET = 'organamnist'
IMAGE_SIZE = 224
BATCH_SIZE = 8 #incresed batch size for OrganAMNIST because of the lazy loading of the data
EPOCHS = 30
LR_VIT = 2e-5
LR_CNN = 1e-4
DROPOUT_META = 0.5
META_BATCH_SIZE = 16
META_EPOCHS = 50
META_PATIENCE = 5
PATIENCE_EARLY = 7
PATIENCE_REDUCE = 3
REDUCE_FACTOR = 0.5
MIN_LR = 1e-6

OUTPUT_DIR = f"/kaggle/working/{DATASET}_outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Mixed precision for speed
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
print(f"Mixed Precision: {policy.name}")
print(f"Output Dir: {OUTPUT_DIR}")
# Out:
# Mixed Precision: mixed_float16
# Output Dir: /kaggle/working/organamnist_outputs

# %% [markdown]
# ## Data Loading

# %%
# DATA LOADER
# FOR ORGANAMNIST ONLY: LAZY LOADING VERSION


NATIVE_LOAD_SIZE = 128 

def load_medmnist_data(dataset_flag, target_size=224, batch_size=8,
                       native_size=NATIVE_LOAD_SIZE):
    """
    Memory-efficient lazy-loading data loader.
    
    Loads all splits at native_size uint8 from MedMNIST+
    Resizes to target_size and casts to float32 in the tf.data pipeline.
    
    Defaults:
      native_size=128 → ~4 GB memory, near-native quality
      Use native_size=64 if memory still tight (~1 GB total)
      Use native_size=224 if you have >16 GB free RAM (no resize)
    """
    info = INFO[dataset_flag]
    n_classes = len(info['label'])
    DataClass = getattr(medmnist, info['python_class'])

    print(f"Loading {dataset_flag} at native {native_size}x{native_size}...")
    print(f"  Lazy resize to {target_size}x{target_size} in pipeline")
    
    train_data = DataClass(split='train', download=True, size=native_size)
    val_data = DataClass(split='val', download=True, size=native_size)
    test_data = DataClass(split='test', download=True, size=native_size)

    X_train, y_train = train_data.imgs, train_data.labels
    X_val, y_val = val_data.imgs, val_data.labels
    X_test, y_test = test_data.imgs, test_data.labels

    # Grayscale to RGB
    if X_train.shape[-1] != 3 and len(X_train.shape) == 3:
        X_train = np.repeat(X_train[..., np.newaxis], 3, -1)
        X_val = np.repeat(X_val[..., np.newaxis], 3, -1)
        X_test = np.repeat(X_test[..., np.newaxis], 3, -1)

    print(f"  Memory footprint:")
    print(f"    Train: {X_train.nbytes / 1024**2:.1f} MB ({X_train.shape})")
    print(f"    Val:   {X_val.nbytes / 1024**2:.1f} MB ({X_val.shape})")
    print(f"    Test:  {X_test.nbytes / 1024**2:.1f} MB ({X_test.shape})")

    y_train_enc = to_categorical(y_train, n_classes)
    y_val_enc = to_categorical(y_val, n_classes)
    y_test_enc = to_categorical(y_test, n_classes)

    def preprocess(image, label):
        image = tf.cast(image, tf.float32)
        # Only resize if needed (skip if native_size == target_size)
        if native_size != target_size:
            image = tf.image.resize(image, [target_size, target_size], method='bilinear')
        return image, label

    train_ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train_enc))
                .shuffle(1000, seed=SEED)
                .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
                .batch(batch_size)
                .prefetch(tf.data.AUTOTUNE))
    
    val_ds = (tf.data.Dataset.from_tensor_slices((X_val, y_val_enc))
              .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
              .batch(batch_size)
              .prefetch(tf.data.AUTOTUNE))
    
    test_ds = (tf.data.Dataset.from_tensor_slices((X_test, y_test_enc))
               .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
               .batch(batch_size)
               .prefetch(tf.data.AUTOTUNE))

    return train_ds, val_ds, test_ds, n_classes, y_test, X_test, info


# Load with lazy pipeline
train_ds, val_ds, test_ds, n_classes, y_test_true, X_test_raw, dataset_info = load_medmnist_data(DATASET, target_size=IMAGE_SIZE, batch_size=BATCH_SIZE)
y_true_flat = y_test_true.flatten()
y_true_cat = to_categorical(y_true_flat, n_classes)
CLASS_NAMES = [dataset_info['label'][str(i)] for i in range(n_classes)]
print(f"\nClasses: {n_classes}")
print(f"Class Names: {CLASS_NAMES}")
print(f"Test set size: {len(y_true_flat)}")
# Out:
# Loading organamnist at native 128x128...
#   Lazy resize to 224x224 in pipeline
# 100%|██████████| 708M/708M [00:40<00:00, 17.3MB/s]
#   Memory footprint:
#     Train: 1620.0 MB ((34561, 128, 128, 3))
#     Val:   304.3 MB ((6491, 128, 128, 3))
#     Test:  833.3 MB ((17778, 128, 128, 3))
#
# Classes: 11
# Class Names: ['bladder', 'femur-left', 'femur-right', 'heart', 'kidney-left', 'kidney-right', 'liver', 'lung-left', 'lung-right', 'pancreas', 'spleen']
# Test set size: 17778

# %% [markdown]
# ## Class Distribuition Analysis

# %%
# CLASS DISTRIBUTION ANALYSIS

DataClass = getattr(medmnist, dataset_info['python_class'])
train_labels = DataClass(split='train', size=IMAGE_SIZE).labels.flatten()
val_labels = DataClass(split='val', size=IMAGE_SIZE).labels.flatten()
test_labels = DataClass(split='test', size=IMAGE_SIZE).labels.flatten()

dist_rows = []
for i, name in enumerate(CLASS_NAMES):
    train_count = (train_labels == i).sum()
    val_count = (val_labels == i).sum()
    test_count = (test_labels == i).sum()
    total = train_count + val_count + test_count
    dist_rows.append({
        'Class ID': i,
        'Class Name': name,
        'Train': train_count,
        'Val': val_count,
        'Test': test_count,
        'Total': total,
        '% of Total': round(100 * total / (len(train_labels)+len(val_labels)+len(test_labels)), 2)
    })

dist_df = pd.DataFrame(dist_rows)
print("\n=== CLASS DISTRIBUTION TABLE ===")
print(dist_df.to_string(index=False))

ir = dist_df['Train'].max() / dist_df['Train'].min()
print(f"\nImbalance Ratio (IR): {ir:.2f}")
print(f"Total samples: Train={len(train_labels)}, Val={len(val_labels)}, Test={len(test_labels)}")
print(f"Missing values check: Train NaNs={pd.isna(train_labels).sum()}, Test NaNs={pd.isna(test_labels).sum()}")
print(f"Duplicates: handled by MedMNIST v2 official splits (no overlap between train/val/test)")

dist_df.to_csv(f"{OUTPUT_DIR}/class_distribution.csv", index=False)
# Out:
# === CLASS DISTRIBUTION TABLE ===
#  Class ID   Class Name  Train  Val  Test  Total  % of Total
#         0      bladder   1956  321  1036   3313        5.63
#         1   femur-left   1390  233   784   2407        4.09
#         2  femur-right   1357  225   793   2375        4.04
#         3        heart   1474  392   785   2651        4.51
#         4  kidney-left   3963  568  2064   6595       11.21
#         5 kidney-right   3817  637  1965   6419       10.91
#         6        liver   6164 1033  3285  10482       17.82
#         7    lung-left   3919 1033  1747   6699       11.39
#         8   lung-right   3929 1009  1813   6751       11.48
#         9     pancreas   3031  529  1622   5182        8.81
#        10       spleen   3561  511  1884   5956       10.12
#
# Imbalance Ratio (IR): 4.54
# Total samples: Train=34561, Val=6491, Test=17778
# Missing values check: Train NaNs=0, Test NaNs=0
# Duplicates: handled by MedMNIST v2 official splits (no overlap between train/val/test)

# %% [markdown]
# ## Model Factory Function

# %%
# MODEL FACTORY

def get_model(model_name, n_classes, input_shape=(224, 224, 3)):
    """Builds a model with the specified architecture."""
    inputs = layers.Input(shape=input_shape)

    if model_name == 'EfficientNetV2M':
        base = applications.EfficientNetV2M(include_top=False, weights='imagenet', input_tensor=inputs)
        x = layers.GlobalAveragePooling2D()(base.output)
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)

    elif model_name == 'InceptionResNetV2':
        x = layers.Rescaling(1./127.5, offset=-1)(inputs)
        base = applications.InceptionResNetV2(include_top=False, weights='imagenet', input_tensor=x)
        x = layers.GlobalAveragePooling2D()(base.output)
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)

    elif model_name == 'ConvNeXtBase':
        base = applications.ConvNeXtBase(include_top=False, weights='imagenet', input_tensor=inputs)
        x = layers.GlobalAveragePooling2D()(base.output)
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)

    elif model_name == 'ViT-Base':
        x = layers.Rescaling(1./127.5, offset=-1)(inputs)
        x = layers.Permute((3, 1, 2))(x)
        backbone = TFViTForImageClassification.from_pretrained(
            'google/vit-base-patch16-224', num_labels=n_classes,
            ignore_mismatched_sizes=True, use_safetensors=False)
        outputs = backbone.vit(x)[0]
        outputs = backbone.classifier(outputs[:, 0, :])
        outputs = layers.Activation('softmax', dtype='float32')(outputs)

    else:
        raise ValueError(f"Unknown Model: {model_name}")

    return models.Model(inputs=inputs, outputs=outputs, name=model_name)

# %% [markdown]
# ## Trainer Function

# %%
# TRAINER

def train_and_save(model_name):
    print(f"\n{'='*20} TRAINING {model_name} {'='*20}")
    tf.keras.backend.clear_session()
    gc.collect()

    model_path = f"{OUTPUT_DIR}/{model_name}_{DATASET}.keras"
    val_pred_path = f"{OUTPUT_DIR}/{model_name}_val_preds.npy"
    test_pred_path = f"{OUTPUT_DIR}/{model_name}_test_preds.npy"

    if os.path.exists(model_path):
        print(f"Loading existing model: {model_path}")
        model = get_model(model_name, n_classes)
        model.load_weights(model_path)
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    else:
        model = get_model(model_name, n_classes)
        lr = LR_VIT if model_name == 'ViT-Base' else LR_CNN
        model.compile(optimizer=tf.keras.optimizers.Adam(lr),
                      loss='categorical_crossentropy', metrics=['accuracy'])

        cb = [
            ModelCheckpoint(model_path, save_best_only=True, monitor='val_accuracy', mode='max', verbose=1),
            ReduceLROnPlateau(monitor='val_loss', factor=REDUCE_FACTOR, patience=PATIENCE_REDUCE, min_lr=MIN_LR, verbose=1),
            EarlyStopping(monitor='val_accuracy', patience=PATIENCE_EARLY, restore_best_weights=True, verbose=1)
        ]
        model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS, callbacks=cb, verbose=1)
        model.load_weights(model_path)

    # Save predictions
    print(f"Generating predictions...")
    val_preds = model.predict(val_ds, verbose=0)
    test_preds = model.predict(test_ds, verbose=0)
    np.save(val_pred_path, val_preds)
    np.save(test_pred_path, test_preds)

    acc = accuracy_score(y_true_flat, np.argmax(test_preds, axis=1))
    print(f"{model_name} Test Accuracy: {acc:.4f}")

    del model
    gc.collect()
    return acc

# %% [markdown]
# ## Model Training

# %%
train_and_save('EfficientNetV2M')
# Out:
# ==================== TRAINING EfficientNetV2M ====================
# Epoch 1/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.1564 - accuracy: 0.9514
# Epoch 1: val_accuracy improved from -inf to 0.99045, saving model to /kaggle/working/organamnist_outputs/EfficientNetV2M_organamnist.keras
# 4321/4321 [==============================] - 996s 201ms/step - loss: 0.1564 - accuracy: 0.9514 - val_loss: 0.0312 - val_accuracy: 0.9904 - lr: 1.0000e-04
# Epoch 2/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9872
# Epoch 2: val_accuracy did not improve from 0.99045
# 4321/4321 [==============================] - 787s 182ms/step - loss: 0.0435 - accuracy: 0.9872 - val_loss: 0.0355 - val_accuracy: 0.9901 - lr: 1.0000e-04
# Epoch 3/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9917
# Epoch 3: val_accuracy did not improve from 0.99045
# 4321/4321 [==============================] - 787s 182ms/step - loss: 0.0264 - accuracy: 0.9917 - val_loss: 0.0275 - val_accuracy: 0.9903 - lr: 1.0000e-04
# Epoch 4/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9931
# Epoch 4: val_accuracy improved from 0.99045 to 0.99091, saving model to /kaggle/working/organamnist_outputs/EfficientNetV2M_organamnist.keras
# 4321/4321 [==============================] - 751s 174ms/step - loss: 0.0243 - accuracy: 0.9931 - val_loss: 0.0287 - val_accuracy: 0.9909 - lr: 1.0000e-04
# Epoch 5/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9943
# Epoch 5: val_accuracy improved from 0.99091 to 0.99106, saving model to /kaggle/working/organamnist_outputs/EfficientNetV2M_organamnist.keras
# 4321/4321 [==============================] - 741s 171ms/step - loss: 0.0198 - accuracy: 0.9943 - val_loss: 0.0231 - val_accuracy: 0.9911 - lr: 1.0000e-04
# Epoch 6/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9957
# Epoch 6: val_accuracy did not improve from 0.99106
# 4321/4321 [==============================] - 767s 178ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 0.0503 - val_accuracy: 0.9883 - lr: 1.0000e-04
# Epoch 7/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9956
# Epoch 7: val_accuracy did not improve from 0.99106
# 4321/4321 [==============================] - 779s 180ms/step - loss: 0.0143 - accuracy: 0.9956 - val_loss: 0.0297 - val_accuracy: 0.9900 - lr: 1.0000e-04
# Epoch 8/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9967
# Epoch 8: val_accuracy did not improve from 0.99106
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 4321/4321 [==============================] - 783s 181ms/step - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.0324 - val_accuracy: 0.9904 - lr: 1.0000e-04
# Epoch 9/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9990
# Epoch 9: val_accuracy improved from 0.99106 to 0.99707, saving model to /kaggle/working/organamnist_outputs/EfficientNetV2M_organamnist.keras
# 4321/4321 [==============================] - 786s 182ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0094 - val_accuracy: 0.9971 - lr: 5.0000e-05
# Epoch 10/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9992
# Epoch 10: val_accuracy did not improve from 0.99707
# 4321/4321 [==============================] - 693s 160ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0489 - val_accuracy: 0.9881 - lr: 5.0000e-05
# Epoch 11/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995
# Epoch 11: val_accuracy did not improve from 0.99707
# 4321/4321 [==============================] - 698s 161ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0641 - val_accuracy: 0.9886 - lr: 5.0000e-05
# Epoch 12/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9993
# Epoch 12: val_accuracy did not improve from 0.99707
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 4321/4321 [==============================] - 697s 161ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0465 - val_accuracy: 0.9875 - lr: 5.0000e-05
# Epoch 13/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 13: val_accuracy did not improve from 0.99707
# 4321/4321 [==============================] - 705s 163ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0534 - val_accuracy: 0.9881 - lr: 2.5000e-05
# Epoch 14/30
# 4321/4321 [==============================] - ETA: 0s - loss: 8.6853e-04 - accuracy: 0.9997
# Epoch 14: val_accuracy did not improve from 0.99707
# 4321/4321 [==============================] - 707s 164ms/step - loss: 8.6853e-04 - accuracy: 0.9997 - val_loss: 0.0606 - val_accuracy: 0.9851 - lr: 2.5000e-05
# Epoch 15/30
# 4321/4321 [==============================] - ETA: 0s - loss: 3.9768e-04 - accuracy: 0.9999
# Epoch 15: val_accuracy did not improve from 0.99707
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 4321/4321 [==============================] - 705s 163ms/step - loss: 3.9768e-04 - accuracy: 0.9999 - val_loss: 0.0261 - val_accuracy: 0.9925 - lr: 2.5000e-05
# Epoch 16/30
# 4321/4321 [==============================] - ETA: 0s - loss: 4.1208e-04 - accuracy: 0.9999
# Epoch 16: val_accuracy did not improve from 0.99707
# 4321/4321 [==============================] - 722s 167ms/step - loss: 4.1208e-04 - accuracy: 0.9999 - val_loss: 0.0178 - val_accuracy: 0.9960 - lr: 1.2500e-05
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Generating predictions...
# EfficientNetV2M Test Accuracy: 0.9710
# 0.9709753628079649

# %%
train_and_save('ConvNeXtBase')
# Out:
# ==================== TRAINING ConvNeXtBase ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 [==============================] - 2s 0us/step
# Epoch 1/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0866 - accuracy: 0.9727
# Epoch 1: val_accuracy improved from -inf to 0.98675, saving model to /kaggle/working/organamnist_outputs/ConvNeXtBase_organamnist.keras
# 4321/4321 [==============================] - 1371s 271ms/step - loss: 0.0866 - accuracy: 0.9727 - val_loss: 0.0378 - val_accuracy: 0.9868 - lr: 1.0000e-04
# Epoch 2/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9929
# Epoch 2: val_accuracy improved from 0.98675 to 0.99106, saving model to /kaggle/working/organamnist_outputs/ConvNeXtBase_organamnist.keras
# 4321/4321 [==============================] - 970s 224ms/step - loss: 0.0236 - accuracy: 0.9929 - val_loss: 0.0293 - val_accuracy: 0.9911 - lr: 1.0000e-04
# Epoch 3/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9951
# Epoch 3: val_accuracy did not improve from 0.99106
# 4321/4321 [==============================] - 957s 221ms/step - loss: 0.0176 - accuracy: 0.9951 - val_loss: 0.0285 - val_accuracy: 0.9901 - lr: 1.0000e-04
# Epoch 4/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9964
# Epoch 4: val_accuracy did not improve from 0.99106
# 4321/4321 [==============================] - 956s 221ms/step - loss: 0.0137 - accuracy: 0.9964 - val_loss: 0.1271 - val_accuracy: 0.9783 - lr: 1.0000e-04
# Epoch 5/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9966
# Epoch 5: val_accuracy improved from 0.99106 to 0.99769, saving model to /kaggle/working/organamnist_outputs/ConvNeXtBase_organamnist.keras
# 4321/4321 [==============================] - 964s 223ms/step - loss: 0.0135 - accuracy: 0.9966 - val_loss: 0.0056 - val_accuracy: 0.9977 - lr: 1.0000e-04
# Epoch 6/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9979
# Epoch 6: val_accuracy did not improve from 0.99769
# 4321/4321 [==============================] - 955s 221ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.0190 - val_accuracy: 0.9934 - lr: 1.0000e-04
# Epoch 7/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9975
# Epoch 7: val_accuracy did not improve from 0.99769
# 4321/4321 [==============================] - 953s 221ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.0206 - val_accuracy: 0.9945 - lr: 1.0000e-04
# Epoch 8/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9977
# Epoch 8: val_accuracy did not improve from 0.99769
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 4321/4321 [==============================] - 953s 221ms/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.0111 - val_accuracy: 0.9957 - lr: 1.0000e-04
# Epoch 9/30
# 4321/4321 [==============================] - ETA: 0s - loss: 9.0345e-04 - accuracy: 0.9997
# Epoch 9: val_accuracy did not improve from 0.99769
# 4321/4321 [==============================] - 954s 221ms/step - loss: 9.0345e-04 - accuracy: 0.9997 - val_loss: 0.0103 - val_accuracy: 0.9965 - lr: 5.0000e-05
# Epoch 10/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 10: val_accuracy did not improve from 0.99769
# 4321/4321 [==============================] - 953s 221ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0082 - val_accuracy: 0.9972 - lr: 5.0000e-05
# Epoch 11/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 11: val_accuracy did not improve from 0.99769
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 4321/4321 [==============================] - 952s 220ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0158 - val_accuracy: 0.9954 - lr: 5.0000e-05
# Epoch 12/30
# 4321/4321 [==============================] - ETA: 0s - loss: 5.0384e-04 - accuracy: 0.9999
# Epoch 12: val_accuracy did not improve from 0.99769
# 4321/4321 [==============================] - 974s 225ms/step - loss: 5.0384e-04 - accuracy: 0.9999 - val_loss: 0.0325 - val_accuracy: 0.9908 - lr: 2.5000e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Generating predictions...
# ConvNeXtBase Test Accuracy: 0.9726
# 0.972550343120711

# %%
train_and_save('ViT-Base')
# Out:
# ==================== TRAINING ViT-Base ====================
# config.json: 0.00B [00:00, ?B/s]
# tf_model.h5:   0%|          | 0.00/347M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFViTForImageClassification.
#
# Some weights of TFViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier/kernel:0: found shape (768, 1000) in the checkpoint and (768, 11) in the model instantiated
# - classifier/bias:0: found shape (1000,) in the checkpoint and (11,) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0901 - accuracy: 0.9734
# Epoch 1: val_accuracy improved from -inf to 0.99676, saving model to /kaggle/working/organamnist_outputs/ViT-Base_organamnist.keras
# 4321/4321 [==============================] - 815s 173ms/step - loss: 0.0901 - accuracy: 0.9734 - val_loss: 0.0103 - val_accuracy: 0.9968 - lr: 2.0000e-05
# Epoch 2/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9959
# Epoch 2: val_accuracy improved from 0.99676 to 0.99707, saving model to /kaggle/working/organamnist_outputs/ViT-Base_organamnist.keras
# 4321/4321 [==============================] - 741s 172ms/step - loss: 0.0133 - accuracy: 0.9959 - val_loss: 0.0073 - val_accuracy: 0.9971 - lr: 2.0000e-05
# Epoch 3/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9974
# Epoch 3: val_accuracy improved from 0.99707 to 0.99784, saving model to /kaggle/working/organamnist_outputs/ViT-Base_organamnist.keras
# 4321/4321 [==============================] - 739s 171ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0060 - val_accuracy: 0.9978 - lr: 2.0000e-05
# Epoch 4/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9980
# Epoch 4: val_accuracy improved from 0.99784 to 0.99815, saving model to /kaggle/working/organamnist_outputs/ViT-Base_organamnist.keras
# 4321/4321 [==============================] - 737s 171ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.0055 - val_accuracy: 0.9982 - lr: 2.0000e-05
# Epoch 5/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9983
# Epoch 5: val_accuracy did not improve from 0.99815
# 4321/4321 [==============================] - 728s 168ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0119 - val_accuracy: 0.9975 - lr: 2.0000e-05
# Epoch 6/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9983
# Epoch 6: val_accuracy improved from 0.99815 to 0.99831, saving model to /kaggle/working/organamnist_outputs/ViT-Base_organamnist.keras
# 4321/4321 [==============================] - 730s 169ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.0106 - val_accuracy: 0.9983 - lr: 2.0000e-05
# Epoch 7/30
# 4321/4321 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9987
# Epoch 7: val_accuracy did not improve from 0.99831
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 4321/4321 [==============================] - 714s 165ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0090 - val_accuracy: 0.9972 - lr: 2.0000e-05
# Epoch 8/30
# 4321/4321 [==============================] - ETA: 0s - loss: 5.0380e-04 - accuracy: 0.9998
# Epoch 8: val_accuracy did not improve from 0.99831
# 4321/4321 [==============================] - 711s 165ms/step - loss: 5.0380e-04 - accuracy: 0.9998 - val_loss: 0.0067 - val_accuracy: 0.9977 - lr: 1.0000e-05
# Epoch 9/30
# 4321/4321 [==============================] - ETA: 0s - loss: 5.9957e-04 - accuracy: 0.9998
# Epoch 9: val_accuracy improved from 0.99831 to 0.99908, saving model to /kaggle/working/organamnist_outputs/ViT-Base_organamnist.keras
# 4321/4321 [==============================] - 710s 164ms/step - loss: 5.9957e-04 - accuracy: 0.9998 - val_loss: 0.0029 - val_accuracy: 0.9991 - lr: 1.0000e-05
# Epoch 10/30
# 4321/4321 [==============================] - ETA: 0s - loss: 1.0904e-04 - accuracy: 0.9999
# Epoch 10: val_accuracy did not improve from 0.99908
# 4321/4321 [==============================] - 705s 163ms/step - loss: 1.0904e-04 - accuracy: 0.9999 - val_loss: 0.0026 - val_accuracy: 0.9991 - lr: 1.0000e-05
# Epoch 11/30
# 4321/4321 [==============================] - ETA: 0s - loss: 3.9889e-06 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.99908
# 4321/4321 [==============================] - 700s 162ms/step - loss: 3.9889e-06 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9991 - lr: 1.0000e-05
# Epoch 12/30
# 4321/4321 [==============================] - ETA: 0s - loss: 9.6491e-07 - accuracy: 1.0000
# Epoch 12: val_accuracy improved from 0.99908 to 0.99923, saving model to /kaggle/working/organamnist_outputs/ViT-Base_organamnist.keras
# 4321/4321 [==============================] - 708s 164ms/step - loss: 9.6491e-07 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 0.9992 - lr: 1.0000e-05
# Epoch 13/30
# 4321/4321 [==============================] - ETA: 0s - loss: 2.1077e-07 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.99923
# 4321/4321 [==============================] - 700s 162ms/step - loss: 2.1077e-07 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 0.9991 - lr: 1.0000e-05
# Epoch 14/30
# 4321/4321 [==============================] - ETA: 0s - loss: 4.7082e-08 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.99923
# 4321/4321 [==============================] - 701s 162ms/step - loss: 4.7082e-08 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9991 - lr: 1.0000e-05
# Epoch 15/30
# 4321/4321 [==============================] - ETA: 0s - loss: 1.3742e-08 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.99923
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 4321/4321 [==============================] - 702s 162ms/step - loss: 1.3742e-08 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9991 - lr: 1.0000e-05
# Epoch 16/30
# 4321/4321 [==============================] - ETA: 0s - loss: 8.3196e-09 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.99923
# 4321/4321 [==============================] - 710s 164ms/step - loss: 8.3196e-09 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9991 - lr: 5.0000e-06
# Epoch 17/30
# 4321/4321 [==============================] - ETA: 0s - loss: 6.6812e-09 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.99923
# 4321/4321 [==============================] - 726s 168ms/step - loss: 6.6812e-09 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9991 - lr: 5.0000e-06
# Epoch 18/30
# 4321/4321 [==============================] - ETA: 0s - loss: 5.6119e-09 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.99923
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 4321/4321 [==============================] - 727s 168ms/step - loss: 5.6119e-09 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9991 - lr: 5.0000e-06
# Epoch 19/30
# 4321/4321 [==============================] - ETA: 0s - loss: 4.9221e-09 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.99923
# 4321/4321 [==============================] - 727s 168ms/step - loss: 4.9221e-09 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9991 - lr: 2.5000e-06
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Generating predictions...
# ViT-Base Test Accuracy: 0.9807
# 0.9806502418719766

# %%
train_and_save('InceptionResNetV2')
