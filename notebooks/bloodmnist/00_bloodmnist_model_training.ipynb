# %% [markdown]
# # BloodMNIST Model Training

# %% [markdown]
# ## Setup and Reproducibility

# %% [markdown]
# !pip install -q "numpy==1.26.4" "scipy==1.13.1"
#
# !pip install -q "transformers==4.44.2" --no-deps
#
# !pip install -q "tokenizers>=0.19,<0.20" "huggingface-hub>=0.23,<0.25" "safetensors>=0.4"
#
# !pip install -q "medmnist" "tf-keras"

# %%
# SETUP AND REPRODUCIBILITY

import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"
os.environ['PYTHONHASHSEED'] = '42'

import random
import numpy as np
import tensorflow as tf

# Global reproducibility seed
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.keras.utils.set_random_seed(SEED)
tf.config.experimental.enable_op_determinism()

# Imports
import medmnist
from medmnist import INFO
import gc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import layers, models, applications, mixed_precision, callbacks
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from transformers import TFViTForImageClassification
from sklearn.metrics import (classification_report, confusion_matrix, accuracy_score,
                              roc_auc_score, precision_score, recall_score, f1_score,
                              average_precision_score, log_loss)
from sklearn.calibration import calibration_curve
from scipy.signal import find_peaks
from scipy.stats import gaussian_kde
import warnings
warnings.filterwarnings('ignore')

print(f"NumPy: {np.__version__}")
print(f"TensorFlow: {tf.__version__}")
print(f"Random Seed: {SEED}")
print(f"Legacy Keras: {os.environ.get('TF_USE_LEGACY_KERAS')}")
# Out:
# 2026-06-07 09:35:17.958296: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780824918.353912     135 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780824918.468998     135 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780824919.451023     135 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780824919.451068     135 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780824919.451070     135 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780824919.451073     135 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# NumPy: 1.26.4
# TensorFlow: 2.19.0
# Random Seed: 42
# Legacy Keras: 1

# %% [markdown]
# ## Configuration

# %%
# CONFIGURATION

DATASET = 'bloodmnist'
IMAGE_SIZE = 224
BATCH_SIZE = 4
EPOCHS = 30
LR_VIT = 2e-5
LR_CNN = 1e-4
DROPOUT_META = 0.5
META_BATCH_SIZE = 16
META_EPOCHS = 50
META_PATIENCE = 5
PATIENCE_EARLY = 7
PATIENCE_REDUCE = 3
REDUCE_FACTOR = 0.5
MIN_LR = 1e-6

OUTPUT_DIR = f"/kaggle/working/{DATASET}_outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Mixed precision for speed
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
print(f"Mixed Precision: {policy.name}")
print(f"Output Dir: {OUTPUT_DIR}")
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPUs will likely run quickly with dtype policy mixed_float16 as they all have compute capability of at least 7.0
# Mixed Precision: mixed_float16
# Output Dir: /kaggle/working/bloodmnist_outputs

# %% [markdown]
# ## Data Loading

# %%
# DATA LOADER

def load_medmnist_data(dataset_flag, size=224, batch_size=8):
    """Loads MedMNIST v2 dataset and prepares tf.data pipelines."""
    info = INFO[dataset_flag]
    n_classes = len(info['label'])
    DataClass = getattr(medmnist, info['python_class'])

    print(f"Loading {dataset_flag}...")
    train_data = DataClass(split='train', download=True, size=size)
    val_data = DataClass(split='val', download=True, size=size)
    test_data = DataClass(split='test', download=True, size=size)

    X_train, y_train = train_data.imgs, train_data.labels
    X_val, y_val = val_data.imgs, val_data.labels
    X_test, y_test = test_data.imgs, test_data.labels

    # Convert grayscale to RGB if needed
    if X_train.shape[-1] != 3:
        X_train = np.repeat(X_train[..., np.newaxis], 3, -1)
        X_val = np.repeat(X_val[..., np.newaxis], 3, -1)
        X_test = np.repeat(X_test[..., np.newaxis], 3, -1)

    X_train = X_train.astype('float32')
    X_val = X_val.astype('float32')
    X_test = X_test.astype('float32')

    y_train_enc = to_categorical(y_train, n_classes)
    y_val_enc = to_categorical(y_val, n_classes)
    y_test_enc = to_categorical(y_test, n_classes)

    train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train_enc))\
        .shuffle(1000, seed=SEED).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val_enc)).batch(batch_size)
    test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test_enc)).batch(batch_size)

    return train_ds, val_ds, test_ds, n_classes, y_test, X_test, info

train_ds, val_ds, test_ds, n_classes, y_test_true, X_test_raw, dataset_info = \
    load_medmnist_data(DATASET, size=IMAGE_SIZE, batch_size=BATCH_SIZE)
y_true_flat = y_test_true.flatten()
y_true_cat = to_categorical(y_true_flat, n_classes)
CLASS_NAMES = [dataset_info['label'][str(i)] for i in range(n_classes)]
print(f"Classes: {n_classes}")
print(f"Class Names: {CLASS_NAMES}")
print(f"Test set size: {len(y_true_flat)}")
# Out:
# Loading bloodmnist...
# 100%|██████████| 1.54G/1.54G [01:01<00:00, 24.9MB/s]
# I0000 00:00:1780825080.159581     135 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1780825080.165804     135 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Classes: 8
# Class Names: ['basophil', 'eosinophil', 'erythroblast', 'immature granulocytes(myelocytes, metamyelocytes and promyelocytes)', 'lymphocyte', 'monocyte', 'neutrophil', 'platelet']
# Test set size: 3421

# %% [markdown]
# ## Class Distribution Analysis

# %%
# CLASS DISTRIBUTION ANALYSIS

DataClass = getattr(medmnist, dataset_info['python_class'])
train_labels = DataClass(split='train', size=IMAGE_SIZE).labels.flatten()
val_labels = DataClass(split='val', size=IMAGE_SIZE).labels.flatten()
test_labels = DataClass(split='test', size=IMAGE_SIZE).labels.flatten()

dist_rows = []
for i, name in enumerate(CLASS_NAMES):
    train_count = (train_labels == i).sum()
    val_count = (val_labels == i).sum()
    test_count = (test_labels == i).sum()
    total = train_count + val_count + test_count
    dist_rows.append({
        'Class ID': i,
        'Class Name': name,
        'Train': train_count,
        'Val': val_count,
        'Test': test_count,
        'Total': total,
        '% of Total': round(100 * total / (len(train_labels)+len(val_labels)+len(test_labels)), 2)
    })

dist_df = pd.DataFrame(dist_rows)
print("\n=== CLASS DISTRIBUTION TABLE ===")
print(dist_df.to_string(index=False))

ir = dist_df['Train'].max() / dist_df['Train'].min()
print(f"\nImbalance Ratio (IR): {ir:.2f}")
print(f"Total samples: Train={len(train_labels)}, Val={len(val_labels)}, Test={len(test_labels)}")
print(f"Missing values check: Train NaNs={pd.isna(train_labels).sum()}, Test NaNs={pd.isna(test_labels).sum()}")
print(f"Duplicates: handled by MedMNIST v2 official splits (no overlap between train/val/test)")

dist_df.to_csv(f"{OUTPUT_DIR}/class_distribution.csv", index=False)
# Out:
# === CLASS DISTRIBUTION TABLE ===
#  Class ID                                                          Class Name  Train  Val  Test  Total  % of Total
#         0                                                            basophil    852  122   244   1218        7.13
#         1                                                          eosinophil   2181  312   624   3117       18.24
#         2                                                        erythroblast   1085  155   311   1551        9.07
#         3 immature granulocytes(myelocytes, metamyelocytes and promyelocytes)   2026  290   579   2895       16.94
#         4                                                          lymphocyte    849  122   243   1214        7.10
#         5                                                            monocyte    993  143   284   1420        8.31
#         6                                                          neutrophil   2330  333   666   3329       19.48
#         7                                                            platelet   1643  235   470   2348       13.74
#
# Imbalance Ratio (IR): 2.74
# Total samples: Train=11959, Val=1712, Test=3421
# Missing values check: Train NaNs=0, Test NaNs=0
# Duplicates: handled by MedMNIST v2 official splits (no overlap between train/val/test)

# %% [markdown]
# ## Model Factory Function

# %%
# MODEL FACTORY

def get_model(model_name, n_classes, input_shape=(224, 224, 3)):
    """Builds a model with the specified architecture."""
    inputs = layers.Input(shape=input_shape)

    if model_name == 'EfficientNetV2M':
        base = applications.EfficientNetV2M(include_top=False, weights='imagenet', input_tensor=inputs)
        x = layers.GlobalAveragePooling2D()(base.output)
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)

    elif model_name == 'InceptionResNetV2':
        x = layers.Rescaling(1./127.5, offset=-1)(inputs)
        base = applications.InceptionResNetV2(include_top=False, weights='imagenet', input_tensor=x)
        x = layers.GlobalAveragePooling2D()(base.output)
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)

    elif model_name == 'ConvNeXtBase':
        base = applications.ConvNeXtBase(include_top=False, weights='imagenet', input_tensor=inputs)
        x = layers.GlobalAveragePooling2D()(base.output)
        outputs = layers.Dense(n_classes, activation='softmax', dtype='float32')(x)

    elif model_name == 'ViT-Base':
        x = layers.Rescaling(1./127.5, offset=-1)(inputs)
        x = layers.Permute((3, 1, 2))(x)
        backbone = TFViTForImageClassification.from_pretrained(
            'google/vit-base-patch16-224', num_labels=n_classes,
            ignore_mismatched_sizes=True, use_safetensors=False)
        outputs = backbone.vit(x)[0]
        outputs = backbone.classifier(outputs[:, 0, :])
        outputs = layers.Activation('softmax', dtype='float32')(outputs)

    else:
        raise ValueError(f"Unknown Model: {model_name}")

    return models.Model(inputs=inputs, outputs=outputs, name=model_name)

# %% [markdown]
# ## Trainer Function

# %%
# TRAINER

def train_and_save(model_name):
    print(f"\n{'='*20} TRAINING {model_name} {'='*20}")
    tf.keras.backend.clear_session()
    gc.collect()

    model_path = f"{OUTPUT_DIR}/{model_name}_{DATASET}.keras"
    val_pred_path = f"{OUTPUT_DIR}/{model_name}_val_preds.npy"
    test_pred_path = f"{OUTPUT_DIR}/{model_name}_test_preds.npy"

    if os.path.exists(model_path):
        print(f"Loading existing model: {model_path}")
        model = get_model(model_name, n_classes)
        model.load_weights(model_path)
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    else:
        model = get_model(model_name, n_classes)
        lr = LR_VIT if model_name == 'ViT-Base' else LR_CNN
        model.compile(optimizer=tf.keras.optimizers.Adam(lr),
                      loss='categorical_crossentropy', metrics=['accuracy'])

        cb = [
            ModelCheckpoint(model_path, save_best_only=True, monitor='val_accuracy', mode='max', verbose=1),
            ReduceLROnPlateau(monitor='val_loss', factor=REDUCE_FACTOR, patience=PATIENCE_REDUCE, min_lr=MIN_LR, verbose=1),
            EarlyStopping(monitor='val_accuracy', patience=PATIENCE_EARLY, restore_best_weights=True, verbose=1)
        ]
        model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS, callbacks=cb, verbose=1)
        model.load_weights(model_path)

    # Save predictions
    print(f"Generating predictions...")
    val_preds = model.predict(val_ds, verbose=0)
    test_preds = model.predict(test_ds, verbose=0)
    np.save(val_pred_path, val_preds)
    np.save(test_pred_path, test_preds)

    acc = accuracy_score(y_true_flat, np.argmax(test_preds, axis=1))
    print(f"{model_name} Test Accuracy: {acc:.4f}")

    del model
    gc.collect()
    return acc

# %% [markdown]
# ## Model Training

# %%
train_and_save('EfficientNetV2M')
# Out:
# ==================== TRAINING EfficientNetV2M ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 1s 0us/step
# Epoch 1/30
# I0000 00:00:1780825224.833207     193 cuda_dnn.cc:529] Loaded cuDNN version 91002
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780825237.336696     194 service.cc:152] XLA service 0x7951322559a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780825237.336741     194 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780825237.336745     194 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780825238.048837     193 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2990/2990 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.9228
# Epoch 1: val_accuracy improved from -inf to 0.98306, saving model to /kaggle/working/bloodmnist_outputs/EfficientNetV2M_bloodmnist.keras
# 2990/2990 [==============================] - 580s 143ms/step - loss: 0.2565 - accuracy: 0.9228 - val_loss: 0.0674 - val_accuracy: 0.9831 - lr: 1.0000e-04
# Epoch 2/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9726
# Epoch 2: val_accuracy did not improve from 0.98306
# 2990/2990 [==============================] - 406s 136ms/step - loss: 0.0919 - accuracy: 0.9726 - val_loss: 0.0794 - val_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 3/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0630 - accuracy: 0.9813
# Epoch 3: val_accuracy improved from 0.98306 to 0.98715, saving model to /kaggle/working/bloodmnist_outputs/EfficientNetV2M_bloodmnist.keras
# 2990/2990 [==============================] - 411s 138ms/step - loss: 0.0630 - accuracy: 0.9813 - val_loss: 0.0458 - val_accuracy: 0.9871 - lr: 1.0000e-04
# Epoch 4/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9825
# Epoch 4: val_accuracy did not improve from 0.98715
# 2990/2990 [==============================] - 406s 136ms/step - loss: 0.0524 - accuracy: 0.9825 - val_loss: 0.0571 - val_accuracy: 0.9836 - lr: 1.0000e-04
# Epoch 5/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9885
# Epoch 5: val_accuracy did not improve from 0.98715
# 2990/2990 [==============================] - 408s 136ms/step - loss: 0.0367 - accuracy: 0.9885 - val_loss: 0.0570 - val_accuracy: 0.9848 - lr: 1.0000e-04
# Epoch 6/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9898
# Epoch 6: val_accuracy did not improve from 0.98715
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2990/2990 [==============================] - 404s 135ms/step - loss: 0.0360 - accuracy: 0.9898 - val_loss: 0.0660 - val_accuracy: 0.9801 - lr: 1.0000e-04
# Epoch 7/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9972
# Epoch 7: val_accuracy did not improve from 0.98715
# 2990/2990 [==============================] - 404s 135ms/step - loss: 0.0102 - accuracy: 0.9972 - val_loss: 0.0564 - val_accuracy: 0.9871 - lr: 5.0000e-05
# Epoch 8/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9979
# Epoch 8: val_accuracy improved from 0.98715 to 0.99065, saving model to /kaggle/working/bloodmnist_outputs/EfficientNetV2M_bloodmnist.keras
# 2990/2990 [==============================] - 413s 138ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0428 - val_accuracy: 0.9907 - lr: 5.0000e-05
# Epoch 9/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9975
# Epoch 9: val_accuracy did not improve from 0.99065
# 2990/2990 [==============================] - 406s 136ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 0.0572 - val_accuracy: 0.9860 - lr: 5.0000e-05
# Epoch 10/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9985
# Epoch 10: val_accuracy did not improve from 0.99065
# 2990/2990 [==============================] - 406s 136ms/step - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.0495 - val_accuracy: 0.9883 - lr: 5.0000e-05
# Epoch 11/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9979
# Epoch 11: val_accuracy did not improve from 0.99065
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 2990/2990 [==============================] - 405s 135ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.0523 - val_accuracy: 0.9871 - lr: 5.0000e-05
# Epoch 12/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9997
# Epoch 12: val_accuracy did not improve from 0.99065
# 2990/2990 [==============================] - 402s 135ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0581 - val_accuracy: 0.9883 - lr: 2.5000e-05
# Epoch 13/30
# 2990/2990 [==============================] - ETA: 0s - loss: 6.1834e-04 - accuracy: 0.9998
# Epoch 13: val_accuracy improved from 0.99065 to 0.99124, saving model to /kaggle/working/bloodmnist_outputs/EfficientNetV2M_bloodmnist.keras
# 2990/2990 [==============================] - 412s 138ms/step - loss: 6.1834e-04 - accuracy: 0.9998 - val_loss: 0.0448 - val_accuracy: 0.9912 - lr: 2.5000e-05
# Epoch 14/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9994
# Epoch 14: val_accuracy did not improve from 0.99124
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 2990/2990 [==============================] - 405s 135ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0503 - val_accuracy: 0.9883 - lr: 2.5000e-05
# Epoch 15/30
# 2990/2990 [==============================] - ETA: 0s - loss: 3.0363e-04 - accuracy: 0.9999
# Epoch 15: val_accuracy did not improve from 0.99124
# 2990/2990 [==============================] - 408s 136ms/step - loss: 3.0363e-04 - accuracy: 0.9999 - val_loss: 0.0506 - val_accuracy: 0.9912 - lr: 1.2500e-05
# Epoch 16/30
# 2990/2990 [==============================] - ETA: 0s - loss: 2.8062e-04 - accuracy: 0.9999
# Epoch 16: val_accuracy did not improve from 0.99124
# 2990/2990 [==============================] - 406s 136ms/step - loss: 2.8062e-04 - accuracy: 0.9999 - val_loss: 0.0685 - val_accuracy: 0.9912 - lr: 1.2500e-05
# Epoch 17/30
# 2990/2990 [==============================] - ETA: 0s - loss: 2.5192e-04 - accuracy: 0.9998
# Epoch 17: val_accuracy did not improve from 0.99124
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 2990/2990 [==============================] - 406s 136ms/step - loss: 2.5192e-04 - accuracy: 0.9998 - val_loss: 0.0723 - val_accuracy: 0.9907 - lr: 1.2500e-05
# Epoch 18/30
# 2990/2990 [==============================] - ETA: 0s - loss: 7.0749e-05 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.99124
# 2990/2990 [==============================] - 403s 135ms/step - loss: 7.0749e-05 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9907 - lr: 6.2500e-06
# Epoch 19/30
# 2990/2990 [==============================] - ETA: 0s - loss: 1.1970e-04 - accuracy: 0.9999
# Epoch 19: val_accuracy did not improve from 0.99124
# 2990/2990 [==============================] - 398s 133ms/step - loss: 1.1970e-04 - accuracy: 0.9999 - val_loss: 0.0732 - val_accuracy: 0.9907 - lr: 6.2500e-06
# Epoch 20/30
# 2990/2990 [==============================] - ETA: 0s - loss: 1.5298e-04 - accuracy: 1.0000
# Epoch 20: val_accuracy improved from 0.99124 to 0.99299, saving model to /kaggle/working/bloodmnist_outputs/EfficientNetV2M_bloodmnist.keras
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 2990/2990 [==============================] - 407s 136ms/step - loss: 1.5298e-04 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9930 - lr: 6.2500e-06
# Epoch 21/30
# 2990/2990 [==============================] - ETA: 0s - loss: 2.5117e-05 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.99299
# 2990/2990 [==============================] - 405s 135ms/step - loss: 2.5117e-05 - accuracy: 1.0000 - val_loss: 0.0724 - val_accuracy: 0.9924 - lr: 3.1250e-06
# Epoch 22/30
# 2990/2990 [==============================] - ETA: 0s - loss: 1.0931e-04 - accuracy: 0.9999
# Epoch 22: val_accuracy did not improve from 0.99299
# 2990/2990 [==============================] - 403s 135ms/step - loss: 1.0931e-04 - accuracy: 0.9999 - val_loss: 0.0616 - val_accuracy: 0.9930 - lr: 3.1250e-06
# Epoch 23/30
# 2990/2990 [==============================] - ETA: 0s - loss: 4.8642e-05 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.99299
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 2990/2990 [==============================] - 407s 136ms/step - loss: 4.8642e-05 - accuracy: 1.0000 - val_loss: 0.0709 - val_accuracy: 0.9907 - lr: 3.1250e-06
# Epoch 24/30
# 2990/2990 [==============================] - ETA: 0s - loss: 1.0389e-04 - accuracy: 0.9999
# Epoch 24: val_accuracy did not improve from 0.99299
# 2990/2990 [==============================] - 406s 136ms/step - loss: 1.0389e-04 - accuracy: 0.9999 - val_loss: 0.0976 - val_accuracy: 0.9877 - lr: 1.5625e-06
# Epoch 25/30
# 2990/2990 [==============================] - ETA: 0s - loss: 1.5026e-05 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.99299
# 2990/2990 [==============================] - 404s 135ms/step - loss: 1.5026e-05 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 0.9912 - lr: 1.5625e-06
# Epoch 26/30
# 2990/2990 [==============================] - ETA: 0s - loss: 1.0440e-05 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.99299
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1e-06.
# 2990/2990 [==============================] - 405s 135ms/step - loss: 1.0440e-05 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9912 - lr: 1.5625e-06
# Epoch 27/30
# 2990/2990 [==============================] - ETA: 0s - loss: 1.3471e-05 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.99299
# 2990/2990 [==============================] - 406s 136ms/step - loss: 1.3471e-05 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 0.9918 - lr: 1.0000e-06
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Generating predictions...
# EfficientNetV2M Test Accuracy: 0.9918
# 0.9918152586962876

# %%
train_and_save('ConvNeXtBase')
# Out:
# ==================== TRAINING ConvNeXtBase ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 [==============================] - 2s 0us/step
# Epoch 1/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.1558 - accuracy: 0.9499
# Epoch 1: val_accuracy improved from -inf to 0.96846, saving model to /kaggle/working/bloodmnist_outputs/ConvNeXtBase_bloodmnist.keras
# 2990/2990 [==============================] - 744s 192ms/step - loss: 0.1558 - accuracy: 0.9499 - val_loss: 0.0999 - val_accuracy: 0.9685 - lr: 1.0000e-04
# Epoch 2/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9816
# Epoch 2: val_accuracy improved from 0.96846 to 0.97605, saving model to /kaggle/working/bloodmnist_outputs/ConvNeXtBase_bloodmnist.keras
# 2990/2990 [==============================] - 462s 155ms/step - loss: 0.0642 - accuracy: 0.9816 - val_loss: 0.0777 - val_accuracy: 0.9761 - lr: 1.0000e-04
# Epoch 3/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9849
# Epoch 3: val_accuracy did not improve from 0.97605
# 2990/2990 [==============================] - 453s 151ms/step - loss: 0.0471 - accuracy: 0.9849 - val_loss: 0.1016 - val_accuracy: 0.9731 - lr: 1.0000e-04
# Epoch 4/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9902
# Epoch 4: val_accuracy improved from 0.97605 to 0.98131, saving model to /kaggle/working/bloodmnist_outputs/ConvNeXtBase_bloodmnist.keras
# 2990/2990 [==============================] - 459s 154ms/step - loss: 0.0293 - accuracy: 0.9902 - val_loss: 0.0829 - val_accuracy: 0.9813 - lr: 1.0000e-04
# Epoch 5/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9916
# Epoch 5: val_accuracy improved from 0.98131 to 0.98248, saving model to /kaggle/working/bloodmnist_outputs/ConvNeXtBase_bloodmnist.keras
# 2990/2990 [==============================] - 459s 154ms/step - loss: 0.0255 - accuracy: 0.9916 - val_loss: 0.0493 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 6/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9953
# Epoch 6: val_accuracy improved from 0.98248 to 0.98890, saving model to /kaggle/working/bloodmnist_outputs/ConvNeXtBase_bloodmnist.keras
# 2990/2990 [==============================] - 460s 154ms/step - loss: 0.0160 - accuracy: 0.9953 - val_loss: 0.0419 - val_accuracy: 0.9889 - lr: 1.0000e-04
# Epoch 7/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9943
# Epoch 7: val_accuracy improved from 0.98890 to 0.98949, saving model to /kaggle/working/bloodmnist_outputs/ConvNeXtBase_bloodmnist.keras
# 2990/2990 [==============================] - 459s 154ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0427 - val_accuracy: 0.9895 - lr: 1.0000e-04
# Epoch 8/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9967
# Epoch 8: val_accuracy did not improve from 0.98949
# 2990/2990 [==============================] - 453s 151ms/step - loss: 0.0143 - accuracy: 0.9967 - val_loss: 0.1425 - val_accuracy: 0.9696 - lr: 1.0000e-04
# Epoch 9/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9948
# Epoch 9: val_accuracy did not improve from 0.98949
# 2990/2990 [==============================] - 451s 151ms/step - loss: 0.0242 - accuracy: 0.9948 - val_loss: 0.0330 - val_accuracy: 0.9883 - lr: 1.0000e-04
# Epoch 10/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9966
# Epoch 10: val_accuracy improved from 0.98949 to 0.99124, saving model to /kaggle/working/bloodmnist_outputs/ConvNeXtBase_bloodmnist.keras
# 2990/2990 [==============================] - 459s 153ms/step - loss: 0.0133 - accuracy: 0.9966 - val_loss: 0.0346 - val_accuracy: 0.9912 - lr: 1.0000e-04
# Epoch 11/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9975
# Epoch 11: val_accuracy did not improve from 0.99124
# 2990/2990 [==============================] - 453s 151ms/step - loss: 0.0112 - accuracy: 0.9975 - val_loss: 0.0408 - val_accuracy: 0.9883 - lr: 1.0000e-04
# Epoch 12/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9956
# Epoch 12: val_accuracy did not improve from 0.99124
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2990/2990 [==============================] - 452s 151ms/step - loss: 0.0155 - accuracy: 0.9956 - val_loss: 0.0409 - val_accuracy: 0.9907 - lr: 1.0000e-04
# Epoch 13/30
# 2990/2990 [==============================] - ETA: 0s - loss: 3.4698e-04 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.99124
# 2990/2990 [==============================] - 451s 151ms/step - loss: 3.4698e-04 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 0.9901 - lr: 5.0000e-05
# Epoch 14/30
# 2990/2990 [==============================] - ETA: 0s - loss: 3.1127e-05 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.99124
# 2990/2990 [==============================] - 451s 151ms/step - loss: 3.1127e-05 - accuracy: 1.0000 - val_loss: 0.0477 - val_accuracy: 0.9907 - lr: 5.0000e-05
# Epoch 15/30
# 2990/2990 [==============================] - ETA: 0s - loss: 5.4139e-06 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.99124
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 2990/2990 [==============================] - 451s 151ms/step - loss: 5.4139e-06 - accuracy: 1.0000 - val_loss: 0.0525 - val_accuracy: 0.9907 - lr: 5.0000e-05
# Epoch 16/30
# 2990/2990 [==============================] - ETA: 0s - loss: 1.3456e-06 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.99124
# 2990/2990 [==============================] - 450s 151ms/step - loss: 1.3456e-06 - accuracy: 1.0000 - val_loss: 0.0557 - val_accuracy: 0.9912 - lr: 2.5000e-05
# Epoch 17/30
# 2990/2990 [==============================] - ETA: 0s - loss: 4.7714e-07 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.99124
# 2990/2990 [==============================] - 451s 151ms/step - loss: 4.7714e-07 - accuracy: 1.0000 - val_loss: 0.0604 - val_accuracy: 0.9912 - lr: 2.5000e-05
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Generating predictions...
# ConvNeXtBase Test Accuracy: 0.9895
# 0.9894767611809413

# %%
train_and_save('ViT-Base')
# Out:
# ==================== TRAINING ViT-Base ====================
# config.json: 0.00B [00:00, ?B/s]
# tf_model.h5:   0%|          | 0.00/347M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFViTForImageClassification.
#
# Some weights of TFViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier/kernel:0: found shape (768, 1000) in the checkpoint and (768, 8) in the model instantiated
# - classifier/bias:0: found shape (1000,) in the checkpoint and (8,) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9615
# Epoch 1: val_accuracy improved from -inf to 0.98306, saving model to /kaggle/working/bloodmnist_outputs/ViT-Base_bloodmnist.keras
# 2990/2990 [==============================] - 378s 111ms/step - loss: 0.1241 - accuracy: 0.9615 - val_loss: 0.0616 - val_accuracy: 0.9831 - lr: 2.0000e-05
# Epoch 2/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9880
# Epoch 2: val_accuracy improved from 0.98306 to 0.99241, saving model to /kaggle/working/bloodmnist_outputs/ViT-Base_bloodmnist.keras
# 2990/2990 [==============================] - 331s 111ms/step - loss: 0.0370 - accuracy: 0.9880 - val_loss: 0.0329 - val_accuracy: 0.9924 - lr: 2.0000e-05
# Epoch 3/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9930
# Epoch 3: val_accuracy did not improve from 0.99241
# 2990/2990 [==============================] - 325s 109ms/step - loss: 0.0200 - accuracy: 0.9930 - val_loss: 0.0424 - val_accuracy: 0.9871 - lr: 2.0000e-05
# Epoch 4/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9943
# Epoch 4: val_accuracy did not improve from 0.99241
# 2990/2990 [==============================] - 324s 108ms/step - loss: 0.0186 - accuracy: 0.9943 - val_loss: 0.0844 - val_accuracy: 0.9755 - lr: 2.0000e-05
# Epoch 5/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9976
# Epoch 5: val_accuracy did not improve from 0.99241
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 2990/2990 [==============================] - 324s 108ms/step - loss: 0.0090 - accuracy: 0.9976 - val_loss: 0.0330 - val_accuracy: 0.9901 - lr: 2.0000e-05
# Epoch 6/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9990
# Epoch 6: val_accuracy did not improve from 0.99241
# 2990/2990 [==============================] - 323s 108ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0349 - val_accuracy: 0.9907 - lr: 1.0000e-05
# Epoch 7/30
# 2990/2990 [==============================] - ETA: 0s - loss: 2.0175e-04 - accuracy: 1.0000
# Epoch 7: val_accuracy improved from 0.99241 to 0.99357, saving model to /kaggle/working/bloodmnist_outputs/ViT-Base_bloodmnist.keras
# 2990/2990 [==============================] - 330s 110ms/step - loss: 2.0175e-04 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9936 - lr: 1.0000e-05
# Epoch 8/30
# 2990/2990 [==============================] - ETA: 0s - loss: 4.9405e-05 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.99357
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 2990/2990 [==============================] - 323s 108ms/step - loss: 4.9405e-05 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9936 - lr: 1.0000e-05
# Epoch 9/30
# 2990/2990 [==============================] - ETA: 0s - loss: 1.9950e-05 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.99357
# 2990/2990 [==============================] - 323s 108ms/step - loss: 1.9950e-05 - accuracy: 1.0000 - val_loss: 0.0370 - val_accuracy: 0.9936 - lr: 5.0000e-06
# Epoch 10/30
# 2990/2990 [==============================] - ETA: 0s - loss: 8.4708e-06 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.99357
# 2990/2990 [==============================] - 323s 108ms/step - loss: 8.4708e-06 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9936 - lr: 5.0000e-06
# Epoch 11/30
# 2990/2990 [==============================] - ETA: 0s - loss: 2.9957e-06 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.99357
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 2990/2990 [==============================] - 322s 108ms/step - loss: 2.9957e-06 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9930 - lr: 5.0000e-06
# Epoch 12/30
# 2990/2990 [==============================] - ETA: 0s - loss: 1.2144e-06 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.99357
# 2990/2990 [==============================] - 322s 108ms/step - loss: 1.2144e-06 - accuracy: 1.0000 - val_loss: 0.0460 - val_accuracy: 0.9930 - lr: 2.5000e-06
# Epoch 13/30
# 2990/2990 [==============================] - ETA: 0s - loss: 5.4715e-07 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.99357
# 2990/2990 [==============================] - 322s 108ms/step - loss: 5.4715e-07 - accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 0.9930 - lr: 2.5000e-06
# Epoch 14/30
# 2990/2990 [==============================] - ETA: 0s - loss: 2.3643e-07 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.99357
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 2990/2990 [==============================] - 321s 108ms/step - loss: 2.3643e-07 - accuracy: 1.0000 - val_loss: 0.0511 - val_accuracy: 0.9936 - lr: 2.5000e-06
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Generating predictions...
# ViT-Base Test Accuracy: 0.9901
# 0.9900613855597779

# %%
train_and_save('InceptionResNetV2')
# Out:
# ==================== TRAINING InceptionResNetV2 ====================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 1s 0us/step
# Epoch 1/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.2360 - accuracy: 0.9273
# Epoch 1: val_accuracy improved from -inf to 0.96612, saving model to /kaggle/working/bloodmnist_outputs/InceptionResNetV2_bloodmnist.keras
# 2990/2990 [==============================] - 413s 101ms/step - loss: 0.2360 - accuracy: 0.9273 - val_loss: nan - val_accuracy: 0.9661 - lr: 1.0000e-04
# Epoch 2/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9722
# Epoch 2: val_accuracy improved from 0.96612 to 0.98364, saving model to /kaggle/working/bloodmnist_outputs/InceptionResNetV2_bloodmnist.keras
# 2990/2990 [==============================] - 304s 102ms/step - loss: 0.0932 - accuracy: 0.9722 - val_loss: 0.0789 - val_accuracy: 0.9836 - lr: 1.0000e-04
# Epoch 3/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9798
# Epoch 3: val_accuracy improved from 0.98364 to 0.98540, saving model to /kaggle/working/bloodmnist_outputs/InceptionResNetV2_bloodmnist.keras
# 2990/2990 [==============================] - 304s 102ms/step - loss: 0.0667 - accuracy: 0.9798 - val_loss: 0.0474 - val_accuracy: 0.9854 - lr: 1.0000e-04
# Epoch 4/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0334 - accuracy: 0.9900
# Epoch 4: val_accuracy did not improve from 0.98540
# 2990/2990 [==============================] - 297s 99ms/step - loss: 0.0334 - accuracy: 0.9900 - val_loss: 0.1343 - val_accuracy: 0.9614 - lr: 1.0000e-04
# Epoch 5/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9892
# Epoch 5: val_accuracy improved from 0.98540 to 0.98715, saving model to /kaggle/working/bloodmnist_outputs/InceptionResNetV2_bloodmnist.keras
# 2990/2990 [==============================] - 303s 101ms/step - loss: 0.0343 - accuracy: 0.9892 - val_loss: 0.0405 - val_accuracy: 0.9871 - lr: 1.0000e-04
# Epoch 6/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9921
# Epoch 6: val_accuracy did not improve from 0.98715
# 2990/2990 [==============================] - 294s 98ms/step - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.0654 - val_accuracy: 0.9801 - lr: 1.0000e-04
# Epoch 7/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9928
# Epoch 7: val_accuracy did not improve from 0.98715
# 2990/2990 [==============================] - 291s 97ms/step - loss: 0.0283 - accuracy: 0.9928 - val_loss: 0.1645 - val_accuracy: 0.9474 - lr: 1.0000e-04
# Epoch 8/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9946
# Epoch 8: val_accuracy did not improve from 0.98715
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2990/2990 [==============================] - 289s 97ms/step - loss: 0.0196 - accuracy: 0.9946 - val_loss: 0.5860 - val_accuracy: 0.9106 - lr: 1.0000e-04
# Epoch 9/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9990
# Epoch 9: val_accuracy did not improve from 0.98715
# 2990/2990 [==============================] - 287s 96ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.5226 - val_accuracy: 0.9071 - lr: 5.0000e-05
# Epoch 10/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9989
# Epoch 10: val_accuracy did not improve from 0.98715
# 2990/2990 [==============================] - 288s 96ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 1.8049 - val_accuracy: 0.8989 - lr: 5.0000e-05
# Epoch 11/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9984
# Epoch 11: val_accuracy did not improve from 0.98715
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 2990/2990 [==============================] - 288s 96ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.3903 - val_accuracy: 0.9223 - lr: 5.0000e-05
# Epoch 12/30
# 2990/2990 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9997
# Epoch 12: val_accuracy did not improve from 0.98715
# 2990/2990 [==============================] - 288s 96ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.6603 - val_accuracy: 0.9124 - lr: 2.5000e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Generating predictions...
# InceptionResNetV2 Test Accuracy: 0.9871
# 0.9871382636655949
